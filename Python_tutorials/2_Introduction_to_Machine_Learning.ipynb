# %% [markdown]
# # Chapter 2 Introduction to Machine Learning

# %% [markdown]
# In this chapter, we’ll briefly review machine learning concepts that will be relevant later. We’ll focus in particular on the problem of prediction, that is, to model some output variable as a function of observed input covariates.

# %%
# importing the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import math
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# In this section, we will use simulated data. In the next section we’ll load a real dataset.

# %%
n = 500 #number of observations
x = np.linspace(-4,4, n) #with linspace we can generate a vector of "n" numbers between a range of numbers

random.shuffle(x) 
mu = np.where(x<0,np.cos(2*x) + np.random.rand(n), 1 + np.sin(x) + np.random.rand(n) )

y = mu + 1*np.random.rand(n) 

data = pd.DataFrame(np.array([x,y]).T, columns=['x','y'])

plt.figure(figsize=(18,6))
sns.scatterplot(x,y, color = 'red', label = 'Data')
sns.lineplot(x,mu, color = 'black', label = "Ground truth E[Y|X=x]")
plt.legend()
plt.xlabel("X")
plt.ylabel("Outcome y")
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# Note: If you’d like to run the code below on a different dataset, you can replace the dataset above with another `data.frame` of your choice, and redefine the key variable identifiers (`outcome`, `covariates`) accordingly. Although we try to make the code as general as possible, you may also need to make a few minor changes to the code below; read the comments carefully.

# %% [markdown]
# ## 2.1 Key concepts

# %% [markdown]
# The prediction problem is to accurately guess the value of some output variable $Y_i$ from input variables $X_i$. For example, we might want to predict “house prices given house characteristics such as the number of rooms, age of the building, and so on. The relationship between input and output is modeled in very general terms by some function
# \begin{equation}
#
#   Y_i = f(X_i) + \epsilon_i
# \end{equation}
# where $\epsilon_i$ represents all that is not captured by information obtained from $X_i$ via the mapping $f$. We say that error $\epsilon_i$ is irreducible.
#
# We highlight that \@ref(eq:true-model) is **not modeling a causal relationship** between inputs and outputs. For an extreme example, consider taking $Y_i$ to be “distance from the equator” and $X_i$ to be “average temperature.” We can still think of the problem of guessing (“predicting”) “distance from the equator” given some information about “average temperature,” even though one would expect the former to cause the latter.
#
# In general, we can’t know the “ground truth”  $f$, so we will approximate it from data. Given $n$ data points $\{(X_1, Y_1), \cdots, (X_n, Y_n)\}$, our goal is to obtain an estimated model  $\hat{f}$ such that our predictions $\widehat{Y}_i := \hat{f}(X_i)$ are “close” to the true outcome values $Y_i$ given some criterion. To formalize this, we’ll follow these three steps:
#
# + **Modeling:** Decide on some suitable class of functions that our estimated model may belong to. In machine learning applications the class of functions can be very large and complex (e.g., deep decision trees, forests, high-dimensional linear models, etc). Also, we must decide on a loss function that serves as our criterion to evaluate the quality of our predictions (e.g., mean-squared error).
#
# + **Fitting:** Find the estimate $\hat{f}$ that optimizes the loss function chosen in the previous step (e.g., the tree that minimizes the squared deviation between $\hat{f}(X_i)$ and $Y_i$ in our data).
#
# + **Evaluation:** Evaluate our fitted model $\hat{f}$. That is, if we were given a new, yet unseen, input and output pair $(X',Y')$, we'd like to know if $Y' \approx \hat{f}(X_i)$ by some metric.
#
# For concreteness, let’s work through an example. Let’s say that, given the data simulated above, we’d like to predict $Y_i$ from the first covariate  $X_{i1}$ only. Also, let’s say that our model class will be polynomials of degree $q$ in $X_{i1}$, and we’ll evaluate fit based on mean squared error. That is, $\hat{f}(X_{i1}) = \hat{b}_0 + X_{i1}\hat{b}_1 + \cdots + X_{i1}^q \hat{b}_q$, where the coefficients are obtained by solving the following problem:
# \begin{equation}
#   \hat{b} = \arg\min_b \sum_{i=1}^m
#     \left(Y_i - b_0 - X_{i1}b_1 - \cdots - X_{iq}^q b_q \right)^2
# \end{equation}
# An important question is what is $q$, the degree of the polynomial. It controls the complexity of the model. One may imagine that more complex models are better, but that is not always true, because a very flexible model may try to simply interpolate over the data at hand, but fail to generalize well for new data points. We call this **overfitting**. The main feature of overfitting is **high variance**, in the sense that, if we were given a different data set of the same size, we'd likely get a very different model.
#
# To illustrate, in the figure below we let the degree be  $q=10$ but use only the first few data points. The fitted model is shown in green, and the original data points are in red.

# %%
X = data.loc[:,'x'].values.reshape(-1, 1)
Y = data.loc[:,'y'].values.reshape(-1, 1)


subset = np.arange(0,30)
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split


poly = PolynomialFeatures(degree = 10)
X_poly = poly.fit_transform(X)

poly.fit(X_poly, Y)
lin2 = LinearRegression()
lin2.fit(X_poly[0:30], Y[0:30])

x = data['x']
xgrid = np.linspace(min(x),max(x), 1000)

new_data = pd.DataFrame(xgrid, columns=['x'])

yhat = lin2.predict(poly.fit_transform(new_data))

# Visualising the Polynomial Regression results
plt.figure(figsize=(18,6))
sns.scatterplot(data.loc[subset,'x'],data.loc[subset,'y'], color = 'red', label = 'Data')
plt.plot(xgrid, yhat, color = 'green', label = 'Estimate')
plt.title('Example of overfitting')
plt.xlabel('X')
plt.ylabel('Outcome y')
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# On the other hand, when $q$ is too small relative to our data, we permit only very simple models and may suffer from misspecification bias. We call this **underfitting**. The main feature of underfitting is **high bias** -- the selected model just isn't complex enough to accurately capture the relationship between input and output variables.
#
# To illustrate underfitting, in the figure below we set $q=1$ (a linear fit).

# %%
lin = LinearRegression()

lin.fit(X[0:30], Y[0:30])


x = data['x']
xgrid = np.linspace(min(x),max(x), 1000)

new_data = pd.DataFrame(xgrid, columns=['x'])

yhat = lin.predict(new_data)

plt.figure(figsize=(18,6))
sns.scatterplot(data.loc[subset,'x'],data.loc[subset,'y'], color = 'red', label = 'Data')
plt.plot(xgrid, yhat, color = 'green',label = 'Estimate')
plt.title('Example of underfitting')
plt.xlabel('X')
plt.ylabel('Outcome y')
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# This tension is called the **bias-variance trade-off**: simpler models underfit and have more bias, more complex models overfit and have more variance.
#
# One data-driven way of deciding an appropriate level of complexity is to divide the available data into a training set (where the model is fit) and the validation set (where the model is evaluated). The next snippet of code uses the first half of the data to fit a polynomial of order $q$, and then evaluates that polynomial on the second half. The training MSE estimate decreases monotonically with the polynomial degree, because the model is better able to fit on the training data; the test MSE estimate starts increasing after a while reflecting that the model no longer generalizes well.

# %%
degrees =np.arange(3,21)
train_mse =[]
test_mse =[]
for d in degrees:
    poly =PolynomialFeatures(degree = d, include_bias =False  )
    poly_features = poly.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(poly_features,y, train_size=0.5, random_state=0)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# we have to define valid_size=0.5 (that is 50% of remaining data)

    poly_reg_model = LinearRegression()
    poly_reg_model.fit(X_train, y_train)
    

    
    y_train_pred = poly_reg_model.predict(X_train)
    y_test_pred = poly_reg_model.predict(X_test)

    mse_train= mean_squared_error(y_train, y_train_pred)
    mse_test= mean_squared_error(y_test, y_test_pred)
    
    train_mse.append(mse_train)
    test_mse.append(mse_test)

# %%
fig, ax = plt.subplots(figsize=(18,6))
ax.plot(degrees, train_mse,color ="black", label = "Training")
ax.plot(degrees, test_mse,"r--", label = "Validation")
ax.set_title("MSE Estimates (train test split)", fontsize =14)
ax.set(xlabel = "Polynomial degree", ylabel = "MSE estimate")
ax.annotate("Low bias \n High Variance", xy=(19, 0.23), xycoords='data', xytext=(16, 0.23), textcoords='data',
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3"),)
ax.annotate("High bias \n Low Variance", xy=(5.3, 0.37), xycoords='data', xytext=(7, 0.37), textcoords='data',
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3"),)
# Out:
# Text(7, 0.37, 'High bias \n Low Variance')

# %% [markdown]
# To make better use of the data we will often divide the data into $K$ subsets, or _folds_. Then one fits $K$ models, each using  $K-1$ folds and then evaluation the fitted model on the remaining fold. This is called **k-fold cross-validation**.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
#cv = KFold(n_splits=10, random_state=1, shuffle=True)
scorer = make_scorer
mse =[]

for d in degrees: 
    
    poly =PolynomialFeatures(degree = d, include_bias =False  )
    poly_features = poly.fit_transform(X)
    ols = LinearRegression()
    scorer = make_scorer(mean_squared_error)
    mse_test= cross_val_score(ols, poly_features, y, scoring=scorer, cv =10).mean()
    mse.append(mse_test)

# %%
plt.figure(figsize=(18,6))
plt.plot(degrees, mse)
plt.xlabel('Polynomial degree', fontsize = 14)
plt.ylabel('MSE estimate', fontsize = 14)
plt.title('MSE estimate (K-fold cross validation)', fontsize =16)
#different to r, the models in python got a better performance with more training cause by the
#cross validation and the kfold
# Out:
# Text(0.5, 1.0, 'MSE estimate (K-fold cross validation)')

# %% [markdown]
# A final remark is that, in machine learning applications, the complexity of the model often is allowed to increase with the available data. In the example above, even though we weren’t very successful when fitting a high-dimensional model on very little data, if we had much more data perhaps such a model would be appropriate. The next figure again fits a high order polynomial model, but this time on many data points. Note how, at least in data-rich regions, the model is much better behaved, and tracks the average outcome reasonably well without trying to interpolate wildly of the data points.

# %%
X = data.loc[:,'x'].values.reshape(-1, 1)
Y = data.loc[:,'y'].values.reshape(-1, 1)


subset = np.arange(0,500)

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures


poly = PolynomialFeatures(degree = 15)
X_poly = poly.fit_transform(X)

poly.fit(X_poly, Y)
lin2 = LinearRegression()
lin2.fit(X_poly[0:500], Y[0:500])

x = data['x']
xgrid = np.linspace(min(x),max(x), 1000)

new_data = pd.DataFrame(xgrid, columns=['x'])

yhat = lin2.predict(poly.fit_transform(new_data))

# Visualising the Polynomial Regression results
plt.figure(figsize=(18,6))
sns.scatterplot(data.loc[subset,'x'],data.loc[subset,'y'], color = 'red', label = 'Data')
plt.plot(xgrid, yhat, color = 'green', label = 'Estimate')
sns.lineplot(x,mu, color = 'black', label = "Ground truth E[Y|X=x]")

plt.title('Example of overfitting')
plt.xlabel('X')
plt.ylabel('Outcome y')
# Out:
# Text(0, 0.5, 'Outcome y')

# %% [markdown]
# This is one of the benefits of using machine learning-based models: more data implies more flexible modeling, and therefore potentially better predictive power -- provided that we carefully avoid overfitting.
#
# The example above based on polynomial regression was used mostly for illustration. In practice, there are often better-performing algorithms. We’ll see some of them next.

# %% [markdown]
# ## 2.2 Common machine learning algorithms

# %% [markdown]
# Next, we’ll introduce three machine learning algorithms: (regularized) linear models, trees, and forests. Although this isn't an exhaustive list, these algorithms are common enough that every machine learning practitioner should know about them. They also have convenient `R` packages that allow for easy coding.
#
# In this tutorial, we'll focus heavily on how to **interpret** the output of machine learning models -- or, at least, how not to _mis_-interpret it. However, in this chapter we won’t be making any causal claims about the relationships between variables yet. But please hang tight, as estimating causal effects will be one of the main topics presented in the next chapters.
#
# For the remainder of the chapter we will use a real dataset. Each row in this data set represents the characteristics of a owner-occupied housing unit. Our goal is to predict the (log) price of the housing unit (`LOGVALUE`, our outcome variable) from features such as the size of the lot (`LOT`) and square feet area (`UNITSF`), number of bedrooms (`BEDRMS`) and bathrooms (`BATHS`), year in which it was built (`BUILT`) etc. This dataset comes from the American Housing Survey and was used in [Mullainathan and Spiess (2017, JEP)](https://www.aeaweb.org/articles?id=10.1257/jep.31.2.87). In addition, we will append to this data columns that are pure noise. Ideally, our fitted model should not take them into acccount.

# %%
import requests
import io

url = 'https://docs.google.com/uc?id=1qHr-6nN7pCbU8JUtbRDtMzUKqS9ZlZcR&export=download'
urlData = requests.get(url).content
data = pd.read_csv(io.StringIO(urlData.decode('utf-8')))
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# outcome variable name
outcome = 'LOGVALUE'

# covariates
true_covariates = ['LOT','UNITSF','BUILT','BATHS','BEDRMS','DINING','METRO','CRACKS','REGION','METRO3','PHONE','KITCHEN','MOBILTYP','WINTEROVEN','WINTERKESP','WINTERELSP','WINTERWOOD','WINTERNONE','NEWC','DISH','WASH','DRY','NUNIT2','BURNER','COOK','OVEN','REFR','DENS','FAMRM','HALFB','KITCH','LIVING','OTHFN','RECRM','CLIMB','ELEV','DIRAC','PORCH','AIRSYS','WELL','WELDUS','STEAM','OARSYS']
p_true = len(true_covariates)

# noise covariates added for didactic reasons

p_noise = 20

noise_covariates = []
for x in range(1, p_noise+1):
    noise_covariates.append('noise{0}'.format(x))

covariates = true_covariates + noise_covariates

x_noise = np.random.rand(data.shape[0] * p_noise).reshape(28727,20)
x_noise = pd.DataFrame(x_noise, columns=noise_covariates)
data = pd.concat([data, x_noise], axis=1)

# sample size
n = data.shape[0]

# total number of covariates
p = len(covariates)
p
# Out:
# 63

# %% [markdown]
# Here's the correlation between the first few covariates. Note how, most variables are positively correlated, which is expected since houses with more bedrooms will usually also have more bathrooms, larger area, etc.

# %%
data.head()
# Out:
#     LOGVALUE  REGION  METRO  METRO3  PHONE  KITCHEN  MOBILTYP  WINTEROVEN  \
# 0  13.487006       4      7       2      1        1        -1           2
# 1  13.217674       4      7       2      1        1        -1           2
# 2  13.487006       4      7       2      1        1        -1           2
# 3  13.017003       4      7       2      1        1        -1           2
# 4  13.458836       4      7       2      1        1        -1           2
#
#    WINTERKESP  WINTERELSP  ...   noise11   noise12   noise13   noise14  \
# 0           2           1  ...  0.588120  0.392753  0.977893  0.992292
# 1           2           2  ...  0.296545  0.437414  0.701534  0.268599
# 2           2           2  ...  0.141892  0.076018  0.528149  0.051183
# 3           2           2  ...  0.811315  0.505733  0.548461  0.923861
# 4           2           2  ...  0.869078  0.452861  0.488211  0.646797
#
#     noise15   noise16   noise17   noise18   noise19   noise20
# 0  0.242192  0.608904  0.249478  0.108163  0.879910  0.756860
# 1  0.657488  0.360639  0.058414  0.475941  0.703180  0.541804
# 2  0.635723  0.292080  0.348391  0.118009  0.433873  0.253238
# 3  0.884587  0.532523  0.536901  0.541973  0.088821  0.307968
# 4  0.948942  0.516531  0.707620  0.923205  0.267111  0.983615
#
# [5 rows x 186 columns]

# %%
data.loc[:,covariates[0:8]].corr()
# Out:
#              LOT    UNITSF     BUILT     BATHS    BEDRMS    DINING     METRO  \
# LOT     1.000000  0.064841  0.044639  0.057325  0.009626 -0.015348  0.136258
# UNITSF  0.064841  1.000000  0.143201  0.428723  0.361165  0.214030  0.057441
# BUILT   0.044639  0.143201  1.000000  0.434519  0.215109  0.037468  0.323703
# BATHS   0.057325  0.428723  0.434519  1.000000  0.540230  0.259457  0.189812
# BEDRMS  0.009626  0.361165  0.215109  0.540230  1.000000  0.281846  0.121331
# DINING -0.015348  0.214030  0.037468  0.259457  0.281846  1.000000  0.022026
# METRO   0.136258  0.057441  0.323703  0.189812  0.121331  0.022026  1.000000
# CRACKS  0.016851  0.033548  0.092390  0.062819  0.026779  0.021270  0.057545
#
#           CRACKS
# LOT     0.016851
# UNITSF  0.033548
# BUILT   0.092390
# BATHS   0.062819
# BEDRMS  0.026779
# DINING  0.021270
# METRO   0.057545
# CRACKS  1.000000

# %% [markdown]
# ### 2.2.1 Generalized linear models

# %% [markdown]
# This class of models extends common methods such as linear and logistic regression by adding a penalty to the magnitude of the coefficients. **Lasso** penalizes the absolute value of slope coefficients. For regression problems, it becomes
# \begin{equation}
#
#   \hat{b}_{Lasso} = \arg\min_b \sum_{i=1}^m
#     \left( Y_i - b_0 - X_{i1}b_1 - \cdots - X_{ip}b_p \right)^2
#     - \lambda \sum_{j=1}^p |b_j|
# \end{equation}
#
#
# Similarly, in a regression problem **Ridge** penalizes the sum of squares of the slope coefficients,
# \begin{equation}
#
#   \hat{b}_{Ridge} = \arg\min_b \sum_{i=1}^m
#     \left( Y_i - b_0 - X_{i1}b_1 - \cdots - X_{ip}b_p \right)^2
#     - \lambda \sum_{j=1}^p b_j^2
# \end{equation}
#
# Also, there exists the **Elastic Net** penalization which consists of a convex combination between the other two. In all cases, the scalar parameter
# $\lambda$ controls the complexity of the model. For $\lambda=0$, the problem reduces to the “usual” linear regression. As $\lambda$ increases, we favor simpler models. As we’ll see below, the optimal parameter $\lambda$ is selected via cross-validation.
#
# An important feature of Lasso-type penalization is that it promotes **sparsity** – that is, it forces many coefficients to be exactly zero. This is different from Ridge-type penalization, which forces coefficients to be small.
#
# Another interesting property of these models is that, even though they are called “linear” models, this should actually be understood as **linear in transformations** of the covariates. For example, we could use polynomials or splines (continuous piecewise polynomials) of the covariates and allow for much more flexible models.
#
# In fact, because of the penalization term, problems \@ref(eq:lasso) and \@ref(eq:ridge) remain well-defined and have a unique solution even in **high-dimensional** problems in which the number of coefficients $p$ is larger than the sample size $n$ – that is, our data is “fat” with more columns than rows. These situations can arise either naturally (e.g. genomics problems in which we have hundreds of thousands of gene expression information for a few individuals) or because we are including many transformations of a smaller set of covariates.
#
# Finally, although here we are focusing on regression problems, other generalized linear models such as logistic regression can also be similarly modified by adding a Lasso, Ridge, or Elastic Net-type penalty to similar consequences.
#
# In our example we will use the `glmnet` package; see this [vignette](https://web.stanford.edu/~hastie/glmnet/glmnet_alpha.html) for more information about the package, including how to use glmnet for other types of outcomes (binomial, categorical, multi-valued). The function `cv.glmnet` automatically performs k-fold cross-validation.
#
# Also, to emphasize the point about linearity in transformations of the covariates, we will use splines of our independent variables (i.e., we will use piecewise continuous polynomials of the original covariates). This is done using the function `bs`; see this [primer](https://cran.r-project.org/web/packages/crs/vignettes/spline_primer.pdf) for more information.

# %%
alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)

X = data.loc[:,covariates]
Y = data.loc[:,outcome]

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import make_scorer
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge

# %%
scaler = StandardScaler()
X_transformed = scaler.fit_transform(X)

# %%
lassocv = LassoCV(n_alphas=200, cv=10)

# %%
lassocv.fit(X,Y)
# Out:
# LassoCV(cv=10, n_alphas=200)

# %%
lassocv.score(X,Y)
# Out:
# 0.08003695446424386

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)
scores = np.empty_like(alphas)
for i,a in enumerate(alphas):
    lasso = Lasso()
    lasso.set_params(alpha=a)
    scorer = make_scorer(mean_squared_error)
    scores[i] = cross_val_score(lasso, X, Y, scoring=scorer, cv=10).mean()
    
    
lassocv = LassoCV()
lassocv.fit(X, Y)
lassocv_score = lassocv.score(X, Y)
lassocv_alpha = lassocv.alpha_
print('CV', lassocv.coef_)

plt.plot(alphas, scores, '-ko')
#plt.axhline(lassocv_score, color='b', ls='--')
#plt.axvline(lassocv_alpha, color='b', ls='--')
plt.xlabel(r'$\alpha$')
plt.ylabel('Score')
plt.xscale('log')
#sns.despine(offset=15)
# Out:
# CV [ 2.05211715e-07  1.19729262e-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00]

# %%
import sklearn.datasets
#from sklearn.model_selection import cross_validate as cv
from sklearn import linear_model


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)
scores = np.empty_like(alphas)
for i,a in enumerate(alphas):
    lasso = linear_model.Lasso()
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    scores[i] = lasso.score(X_test, y_test)
    print(a, lasso.coef_)
    
lassocv = linear_model.LassoCV()
lassocv.fit(X, Y)
lassocv_score = lassocv.score(X, Y)
lassocv_alpha = lassocv.alpha_
print('CV', lassocv.coef_)

plt.plot(alphas, scores, '-ko')
#plt.axhline(lassocv_score, color='b', ls='--')
#plt.axvline(lassocv_alpha, color='b', ls='--')
plt.xlabel(r'$\alpha$')
plt.ylabel('Score')
plt.xscale('log')
#sns.despine(offset=15)
# Out:
# 1e-08 [ 3.32596119e-07  1.97793630e-05  2.69626783e-04  2.36400958e-01
#   6.92458967e-02  9.64189843e-02  3.58959783e-03  7.74096885e-02
#   1.21348294e-01  5.93124829e-03  2.82112564e-03 -1.88127199e-01
#  -2.32627646e-01  4.36966253e-02  4.36542668e-03  5.33863097e-02
#  -3.16925418e-02 -3.44624624e-02  1.84438996e-02 -2.29860873e-01
#  -2.03382031e-01 -8.92722864e-02 -3.52355655e-01 -1.07030260e-01
#   7.44440185e-01  1.19627670e-02  6.92272617e-02  1.17454060e-01
#   1.28228393e-01  1.90049226e-01 -1.53727269e-01  2.74933610e-02
#   9.26466041e-02  7.73747593e-02  5.69130470e-02  8.06917282e-02
#  -2.20439291e-02 -2.79255122e-02 -6.23112445e-01 -7.80096602e-02
#  -6.61511491e-02  1.06958865e-02 -5.74120922e-02  4.13284013e-03
#   3.79754338e-02  9.45310891e-03  1.79980155e-02  2.60368670e-02
#   4.63363302e-04 -1.55239317e-02 -1.29017976e-02  2.37653303e-02
#   3.34509669e-02  1.33094851e-02  1.04655947e-02 -1.44350986e-02
#  -2.02575411e-02  5.70590778e-03 -1.68120320e-02  4.70266009e-03
#   2.16224968e-02 -1.27375404e-02  2.54094755e-02]
# 1.176811952434999e-08 [ 3.32596119e-07  1.97793668e-05  2.69626918e-04  2.36400972e-01
#   6.92458979e-02  9.64189879e-02  3.58959869e-03  7.74096628e-02
#   1.21348302e-01  5.93124914e-03  2.82112616e-03 -1.88125607e-01
#  -2.32627649e-01  4.36963614e-02  4.36516777e-03  5.33861113e-02
#  -3.16916436e-02 -3.44626602e-02  1.84438981e-02 -2.29860875e-01
-04  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00]

# %%
alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)
mse_min = []
mse_max = []
mse_mean =[] 
scorer = make_scorer(mean_squared_error)
for i in alphas:
    lasso = Lasso(alpha= i )
    mse_min.append(cross_val_score(lasso, X, Y, scoring=scorer, cv=10).min())
    mse_max.append(cross_val_score(lasso, X, Y, scoring=scorer, cv=10).max())
    mse_mean.append(cross_val_score(lasso, X, Y, scoring=scorer, cv=10).mean())

# %%
lasso_alphas = np.linspace(0, 2, 1000)
lasso= Lasso()
grid = dict()
grid['alpha'] = lasso_alphas
scorer = make_scorer(mean_squared_error)

gscv = GridSearchCV(
    lasso, grid, scoring=scorer,
    cv=10 
)
results = gscv.fit(X, Y)

# %%
lasso = Lasso()
alphas = np.logspace(np.log10(1e-8), np.log10(1e-1), 100)



tuned_parameters = [{"alpha": alphas}]
n_folds = 10

scorer = make_scorer(mean_squared_error)

clf = GridSearchCV(lasso, tuned_parameters, cv=n_folds, refit=False, scoring=scorer)
clf.fit(X, Y)
scores = clf.cv_results_["mean_test_score"]
scores_std = clf.cv_results_["std_test_score"]

# %% [markdown]
# The next figure plots the average estimated MSE for each lambda. The red dots are the averages across all folds, and the error bars are based on the variability of mse estimates across folds. The vertical dashed lines show the (log) lambda with smallest estimated MSE (left) and the one whose mse is at most one standard error from the first (right).

# %%
plt.figure().set_size_inches(8, 6)
plt.semilogx(alphas, scores)


# plot error lines showing +/- std. errors of the scores
std_error = scores_std / np.sqrt(n_folds)

plt.semilogx(alphas, scores + std_error, "b--")
plt.semilogx(alphas, scores - std_error, "b--")

# alpha=0.2 controls the translucency of the fill color
plt.fill_between(alphas, scores + std_error, scores - std_error, alpha=0.2)

plt.ylabel("CV score +/- std error")
plt.xlabel("alpha")
plt.axhline(np.max(scores), linestyle="--", color=".5")
plt.xlim([alphas[0], alphas[-1]])
# Out:
# (1e-08, 0.1)

# %% [markdown]
# Here are the first few estimated coefficients at the $\lambda$ value that minimizes cross-validated MSE. Note that many estimated coefficients them are exactly zero.

# %%
clf.best_params_
# Out:
# {'alpha': 0.1}

# %%
lasso = Lasso(alpha=clf.best_params_['alpha'])
lasso.fit(X,Y)
table = np.zeros((1,5))
table[0,0] = lasso.intercept_
table[0,1] = lasso.coef_[0]
table[0,2] = lasso.coef_[1]
table[0,3] = lasso.coef_[2]
table[0,4] = lasso.coef_[3]
pd.DataFrame(table, columns=['(Intercept)','LOT','UNITSF','BUILT','BATHS'], index=['Coef.'])
# Out:
#        (Intercept)           LOT    UNITSF     BUILT     BATHS
# Coef.     2.680718  2.532409e-07  0.000085  0.004487  0.138486

# %%
print("Number of nonzero coefficients at optimal lambda:", len(lasso.coef_[lasso.coef_ != 0]), "out of " , len(lasso.coef_))
# Out:
# Number of nonzero coefficients at optimal lambda: 7 out of  63

# %% [markdown]
# Predictions and estimated MSE for the selected model are retrieved as follows.

# %%
from sklearn.linear_model import lasso_path
eps = 5e-3 
alphas_lasso, coefs_lasso, _ = lasso_path(X, Y, eps=eps)

# %%
len(coefs_lasso)
# Out:
# 63

# %% [markdown]
# The next command plots estimated coefficients as a function of the regularization parameter $\lambda$.

# %%
coefs = []
for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X, Y)
    coefs.append(lasso.coef_)

# %%
from matplotlib.pyplot import figure

plt.figure(figsize=(18,6))
plt.gca().plot(alphas, coefs)
plt.gca().set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha');

# %% [markdown]
# It's tempting to try to interpret the coefficients obtained via Lasso. Unfortunately, that can be very difficult, because by dropping covariates Lasso introduces a form of **omitted variable bias** ([wikipedia](https://en.wikipedia.org/wiki/Omitted-variable_bias)). To understand this form of bias, consider the following toy example. We have two positively correlated independent variables, `x.1` and `x.2`, that are linearly related to the outcome `y`. Linear regression of `y` on `x1` and `x2` gives us the correct coefficients. However, if we _omit_ `x2` from the estimation model, the coefficient on `x1` increases. This is because `x1` is now "picking up" the effect of the variable that was left out. In other words, the effect of `x1` seems stronger because we aren't controlling for some other confounding variable. Note that the second model this still works for prediction, but we cannot interpret the coefficient as a measure of strength of the causal relationship between `x1` and `y`.

# %%
mean = [0.0,0.0]
cov = [[1.5,0.5],[0.5,1.5]]

x1, x2 = np.random.multivariate_normal(mean, cov, 100000).T
y = 1 + 2*x1 + 3*x2 + np.random.rand(100000)
data_sim = pd.DataFrame(np.array([x1,x2,y]).T,columns=['x1','x2','y'] )

print('Correct Model')
# Out:
# Correct Model

# %%
import statsmodels.formula.api as smf

result = smf.ols('y ~ x1 + x2', data = data_sim).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 1.543e+07
# Date:                Fri, 13 May 2022   Prob (F-statistic):               0.00
# Time:                        05:18:59   Log-Likelihood:                -17440.
# No. Observations:              100000   AIC:                         3.489e+04
# Df Residuals:                   99997   BIC:                         3.492e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4987      0.001   1645.077      0.000       1.497       1.500
# x1             1.9994      0.001   2536.958      0.000       1.998       2.001
# x2             3.0009      0.001   3810.059      0.000       2.999       3.002
# ==============================================================================
# Omnibus:                    86228.541   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5970.265
# Skew:                           0.004   Prob(JB):                         0.00
# Kurtosis:                       1.803   Cond. No.                         1.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print("Model with omitted variable bias")

result = smf.ols('y ~ x1', data = data_sim).fit()
print(result.summary())
# Out:
# Model with omitted variable bias
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                 1.118e+05
# Date:                Fri, 13 May 2022   Prob (F-statistic):               0.00
# Time:                        05:19:01   Log-Likelihood:            -2.6668e+05
# No. Observations:              100000   AIC:                         5.334e+05
# Df Residuals:                   99998   BIC:                         5.334e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4852      0.011    134.848      0.000       1.464       1.507
# x1             3.0030      0.009    334.394      0.000       2.985       3.021
# ==============================================================================
# Omnibus:                        5.691   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                5.807
# Skew:                           0.007   Prob(JB):                       0.0548
# Kurtosis:                       3.035   Cond. No.                         1.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The phenomenon above occurs in Lasso and in any other sparsity-promoting method when correlated covariates are present since, by forcing coefficients to be zero, Lasso is effectively dropping them from the model. And as we have seen, as a variable gets dropped, a different variable that is correlated with it can "pick up" its effect, which in turn can cause bias. Once $\lambda$ grows sufficiently large, the penalization term overwhelms any benefit of having that variable in the model, so that variable finally decreases to zero too.
#
# One may instead consider using Lasso to select a subset of variables, and then regressing the outcome on the subset of selected variables via OLS (without any penalization). This method is often called **post-lasso**. Although it has desirable properties in terms of model fit (see e.g., [Belloni and Chernozhukov, 2013](https://arxiv.org/pdf/1001.0188.pdf)), this procedure does not solve the omitted variable issue we mentioned above.
#
# We illustrate this next. We observe the path of the estimated coefficient on the number of bathroooms (`BATHS`) as we increase $\lambda$.

# %%
scale_X = StandardScaler().fit(X).transform(X)
ols = LinearRegression()
ols.fit(scale_X,Y)
ols_coef = ols.coef_[3]
lamdas = np.linspace(0.01,0.4, 200)


coef_ols = np.repeat(ols_coef,200)
###############################################

lasso_bath_coef = []
lasso_coefs=[]
for a in lamdas:
    lasso.set_params(alpha=a,normalize = False)
    lasso.fit(scale_X, Y)
    lasso_bath_coef.append(lasso.coef_[3])
    lasso_coefs.append(lasso.coef_)
#################################################   

ridge_bath_coef = []
for a in lamdas:
    ridge = Ridge(alpha=a,normalize = True)
    ridge.fit(scale_X, Y)
    ridge_bath_coef.append(ridge.coef_[3])
####################################################

poslasso_coef = [ ]
for a in range(200):
    scale_X = StandardScaler().fit(X.iloc[:, (lasso_coefs[a] !=  0)]).transform(X.iloc[:, (lasso_coefs[a] !=  0)])
    ols = LinearRegression()
    ols.fit(scale_X,Y)  
    post_coef = ols.coef_[X.iloc[:, (lasso_coefs[a] !=  0)].columns.get_loc('BATHS')]                             
    poslasso_coef.append(post_coef )    
    
    
#################################################
plt.figure(figsize=(18,5))
plt.plot(lamdas, ridge_bath_coef, label = 'Ridge', color = 'g', marker='+', linestyle = ':',markevery=8)
plt.plot(lamdas, lasso_bath_coef, label = 'Lasso', color = 'r', marker = '^',linestyle = 'dashed',markevery=8)
plt.plot(lamdas, coef_ols, label = 'OLS', color = 'b',marker = 'x',linestyle = 'dashed',markevery=8)
plt.plot(lamdas, poslasso_coef, label = 'postlasso',color='black',marker = 'o',linestyle = 'dashed',markevery=8 )
plt.legend()
plt.title("Coefficient estimate on Baths")
plt.ylabel('Coef')
plt.xlabel('lambda')
# Out:
# Text(0.5, 0, 'lambda')

# %% [markdown]
# The OLS coefficients are not penalized, so they remain constant. Ridge estimates decrease monotonically as $\lambda$ grows. Also, for this dataset, Lasso estimates first increase and then decrease. Meanwhile, the post-lasso coefficient estimates seem to behave somewhat erratically with $lambda$. To understand this behavior, let's see what happens to the magnitude of other selected variables that are correlated with `BATHS`.

# %%
scale_X = StandardScaler().fit(X).transform(X)
UNITSF_coef = []
BEDRMS_coef = []
DINING_coef = []
for a in lamdas:
    lasso.set_params(alpha=a,normalize = False)
    lasso.fit(scale_X, Y)
    UNITSF_coef.append(lasso.coef_[1])
    BEDRMS_coef.append(lasso.coef_[4])
    DINING_coef.append(lasso.coef_[5])

# %%
plt.figure(figsize=(18,5))
plt.plot(lamdas, UNITSF_coef,label = 'UNITSF', color = 'black' )
plt.plot(lamdas, BEDRMS_coef,label = 'BEDRMS', color = 'red',  linestyle = '--')
plt.plot(lamdas, DINING_coef,label = 'DINING', color = 'g',linestyle = 'dotted')
plt.legend()
plt.ylabel('Coef')
plt.xlabel('lambda')
# Out:
# Text(0.5, 0, 'lambda')

# %% [markdown]
# Note how the discrete jumps in magnitude for the `BATHS` coefficient in the first coincide with, for example, variables `DINING` and `BEDRMS` being exactly zero. As these variables got dropped from the model, the coefficient on `BATHS` increased to pick up their effect.
#
# Another problem with Lasso coefficients is their instability. When multiple variables are highly correlated we may spuriously drop several of them. To get a sense of the amount of variability, in the next snippet we fix $\lambda$ and then look at the lasso coefficients estimated during cross-validation. We see that by simply removing one fold we can get a very different set of coefficients (nonzero coefficients are in black in the heatmap below). This is because there may be many choices of coefficients with similar predictive power, so the set of nonzero coefficients we end up with can be quite unstable.

# %%
import itertools
nobs = X.shape[0]

nfold = 10
    # Define folds indices 
list_1 = [*range(0, nfold, 1)]*nobs
sample = np.random.choice(nobs,nobs, replace=False).tolist()
foldid = [list_1[index] for index in sample]

    # Create split function(similar to R)
def split(x, f):
    count = max(f) + 1
    return tuple( list(itertools.compress(x, (el == i for el in f))) for i in range(count) ) 

    # Split observation indices into folds 
list_2 = [*range(0, nobs, 1)]
I = split(list_2, foldid)

# %%
lasso_coef_fold=[]
for b in range(0,len(I)):
    
        # Split data - index to keep are in mask as booleans
        include_idx = set(I[b])  #Here should go I[b] Set is more efficient, but doesn't reorder your elements if that is desireable
        mask = np.array([(i in include_idx) for i in range(len(X))])

        # Lasso regression, excluding folds selected 
        
        lassocv = LassoCV(random_state=0)
        lassocv.fit(scale_X[~mask], Y[~mask])
        lasso_coef_fold.append(lassocv.coef_)

# %%
index_val = ['Fold-1','Fold-2','Fold-3','Fold-4','Fold-5','Fold-6','Fold-7','Fold-8','Fold-9','Fold-10']
df = pd.DataFrame(data= lasso_coef_fold, columns=X.columns, index = index_val).T
df.style.applymap(lambda x: "background-color: black" if x==0 else "background-color: white")
# Out:
# <style type="text/css">
# #T_153ed_row0_col0, #T_153ed_row0_col1, #T_153ed_row0_col2, #T_153ed_row0_col3, #T_153ed_row0_col4, #T_153ed_row0_col5, #T_153ed_row0_col6, #T_153ed_row0_col7, #T_153ed_row0_col8, #T_153ed_row0_col9, #T_153ed_row1_col0, #T_153ed_row1_col1, #T_153ed_row1_col2, #T_153ed_row1_col3, #T_153ed_row1_col4, #T_153ed_row1_col5, #T_153ed_row1_col6, #T_153ed_row1_col7, #T_153ed_row1_col8, #T_153ed_row1_col9, #T_153ed_row2_col0, #T_153ed_row2_col1, #T_153ed_row2_col2, #T_153ed_row2_col3, #T_153ed_row2_col4, #T_153ed_row2_col5, #T_153ed_row2_col6, #T_153ed_row2_col7, #T_153ed_row2_col8, #T_153ed_row2_col9, #T_153ed_row3_col0, #T_153ed_row3_col1, #T_153ed_row3_col2, #T_153ed_row3_col3, #T_153ed_row3_col4, #T_153ed_row3_col5, #T_153ed_row3_col6, #T_153ed_row3_col7, #T_153ed_row3_col8, #T_153ed_row3_col9, #T_153ed_row4_col0, #T_153ed_row4_col1, #T_153ed_row4_col2, #T_153ed_row4_col3, #T_153ed_row4_col4, #T_153ed_row4_col5, #T_153ed_row4_col6, #T_153ed_row4_col7, #T_153ed_row4_col8, #T_153ed_row4_col9, #T_153ed_row5_col0, #T_153ed_row5_col1, #T_153ed_row5_col2, #T_153ed_row5_col3, #T_153ed_row5_col4, #T_153ed_row5_col5, #T_153ed_row5_col6, #T_153ed_row5_col7, #T_153ed_row5_col8, #T_153ed_row5_col9, #T_153ed_row6_col1, #T_153ed_row6_col2, #T_153ed_row6_col3, #T_153ed_row6_col5, #T_153ed_row6_col6, #T_153ed_row6_col7, #T_153ed_row6_col8, #T_153ed_row7_col0, #T_153ed_row7_col1, #T_153ed_row7_col2, #T_153ed_row7_col3, #T_153ed_row7_col4, #T_153ed_row7_col5, #T_153ed_row7_col6, #T_153ed_row7_col7, #T_153ed_row7_col8, #T_153ed_row7_col9, #T_153ed_row8_col0, #T_153ed_row8_col1, #T_153ed_row8_col2, #T_153ed_row8_col3, #T_153ed_row8_col4, #T_153ed_row8_col5, #T_153ed_row8_col6, #T_153ed_row8_col7, #T_153ed_row8_col8, #T_153ed_row8_col9, #T_153ed_row9_col0, #T_153ed_row9_col1, #T_153ed_row9_col2, #T_153ed_row9_col3, #T_153ed_row9_col4, #T_153ed_row9_col5, #T_153ed_row9_col6, #T_153ed_row9_col7, #T_153ed_row9_col8, #T_153ed_row9_col9, #T_153ed_row10_col0, #T_153ed_row10_col1, #T_153ed_row10_col2, #T_153ed_row10_col3, #T_153ed_row10_col4, #T_153ed_row10_col6, #T_153ed_row10_col7, #T_153ed_row10_col8, #T_153ed_row10_col9, #T_153ed_row11_col0, #T_153ed_row11_col1, #T_153ed_row11_col2, #T_153ed_row11_col3, #T_153ed_row11_col4, #T_153ed_row11_col6, #T_153ed_row11_col7, #T_153ed_row11_col8, #T_153ed_row12_col0, #T_153ed_row12_col1, #T_153ed_row12_col2, #T_153ed_row12_col3, #T_153ed_row12_col4, #T_153ed_row12_col5, #T_153ed_row12_col6, #T_153ed_row12_col7, #T_153ed_row12_col8, #T_153ed_row12_col9, #T_153ed_row15_col0, #T_153ed_row15_col1, #T_153ed_row15_col2, #T_153ed_row15_col3, #T_153ed_row15_col4, #T_153ed_row15_col5, #T_153ed_row15_col6, #T_153ed_row15_col7, #T_153ed_row15_col8, #T_153ed_row15_col9, #T_153ed_row17_col0, #T_153ed_row17_col1, #T_153ed_row17_col2, #T_153ed_row17_col3, #T_153ed_row17_col5, #T_153ed_row17_col6, #T_153ed_row17_col8, #T_153ed_row17_col9, #T_153ed_row18_col0, #T_153ed_row18_col1, #T_153ed_row18_col2, #T_153ed_row18_col3, #T_153ed_row18_col4, #T_153ed_row18_col5, #T_153ed_row18_col6, #T_153ed_row18_col7, #T_153ed_row18_col8, #T_153ed_row18_col9, #T_153ed_row19_col0, #T_153ed_row19_col1, #T_153ed_row19_col2, #T_153ed_row19_col3, #T_153ed_row19_col4, #T_153ed_row19_col5, #T_153ed_row19_col6, #T_153ed_row19_col7, #T_153ed_row19_col8, #T_153ed_row19_col9, #T_153ed_row20_col0, #T_153ed_row20_col1, #T_153ed_row20_col2, #T_153ed_row20_col3, #T_153ed_row20_col4, #T_153ed_row20_col5, #T_153ed_row20_col6, #T_153ed_row20_col7, #T_153ed_row20_col8, #T_153ed_row20_col9, #T_153ed_row21_col0, #T_153ed_row21_col1, #T_153ed_row21_col2, #T_153ed_row21_col3, #T_153ed_row21_col4, #T_153ed_row21_col5, #T_153ed_row21_col6, #T_153ed_row21_col7, #T_153ed_row21_col8, #T_153ed_row21_col9, #T_153ed_row22_col0, #T_153ed_row22_col1, #T_153ed_row22_col2, #T_153ed_row22_col3, #T_153ed_row22_col4, #T_153ed_row22_col5, #T_153ed_row22_col6, #T_153ed_row22_col7, #T_153ed_row22_col8, #T_153ed_row22_col9, #T_153ed_row26_col9, #T_153ed_row27_col0, #T_153ed_row27_col1, #T ...

# %% [markdown]
# As we have seen above, any interpretation needs to take into account the joint distribution of covariates. One possible heuristic is to consider **data-driven subgroups**. For example, we can analyze what differentiates observations whose predictions are high from those whose predictions are low. The following code estimates a flexible Lasso model with splines, ranks the observations into a few subgroups according to their predicted outcomes, and then estimates the average covariate value for each subgroup.

# %% [markdown]
# The next heatmap visualizes the results. Note how observations ranked higher (i.e., were predicted to have higher prices) have more bedrooms and baths, were built more recently, have fewer cracks, and so on. The next snippet of code displays the average covariate per group along with each standard errors. The rows are ordered according to $Var(E[X_{ij} | G_i) / Var(X_i)$, where $G_i$ denotes the ranking. This is a rough normalized measure of how much variation is "explained" by group membership $G_i$. Brighter colors indicate larger values.

# %% [markdown]
# As we just saw above, houses that have, e.g., been built more recently (`BUILT`), have more baths (`BATHS`) are associated with larger price predictions.
#
# This sort of interpretation exercise did not rely on reading any coefficients, and in fact it could also be done using any other flexible method, including decisions trees and forests.

# %% [markdown]
# ### 2.2.2 Decision Tree

# %% [markdown]
# This next class of algorithms divides the covariate space into "regions" and estimates a constant prediction within each region.
#
# To estimate a decision tree, we following a recursive partition algorithm. At each stage, we select one variable $j$ and one split point
# $s$, and divide the observations into “left” and “right” subsets, depending on whether $X_{ij} \leq s$ or $X_{ij} > s$. For regression problems, the variable and split points are often selected so that the sum of the variances of the outcome variable in each “child” subset is smallest. For classification problems, we split to separate the classes. Then, for each child, we separately repeat the process of finding variables and split points. This continues until a minimum subset size is reached, or improvement falls below some threshold.
#
# At prediction time, to find the predictions for some point $x$, we just follow the tree we just built, going left or right according to the selected variables and split points, until we reach a terminal node. Then, for regression problems, the predicted value at some point $x$ is the average outcome of the observations in the same partition as the point $x$. For classification problems, we output the majority class in the node.
#
# Let’s estimate a decision tree using the `R` package rpart; see [this tutorial](https://cran.r-project.org/web/packages/rpart/vignettes/longintro.pdf) for more information about it.

# %%
from sklearn.tree import DecisionTreeRegressor
import graphviz
from sklearn import tree
from sklearn.tree import export_graphviz 
dt = DecisionTreeRegressor(ccp_alpha=0)
dt.fit(X,Y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0)

# %%
yhat = dt.predict(X)
mean_squared_error(Y, yhat)
# Out:
# 1.101170407608263e-32

# %% [markdown]
# At this point, we have not constrained the complexity of the tree in any way, so it's likely too deep and probably overfits. Here’s a plot of what we have so far (without bothering to label the splits to avoid clutter).

# %%
plt.figure(figsize=(18,5))
tree.plot_tree(dt)
# Out:
# [Text(0.7718372264894693, 0.990909090909091, 'X[22] <= 3.5\nsquared_error = 0.969\nsamples = 28727\nvalue = 11.814'),
#  Text(0.5618495832928599, 0.9727272727272728, 'X[1] <= 2436.5\nsquared_error = 0.777\nsamples = 27679\nvalue = 11.887'),
#  Text(0.3005523883837494, 0.9545454545454546, 'X[3] <= 1.5\nsquared_error = 0.648\nsamples = 19823\nvalue = 11.685'),
#  Text(0.1020576650537341, 0.9363636363636364, 'X[19] <= 1.5\nsquared_error = 0.727\nsamples = 7235\nvalue = 11.384'),
#  Text(0.02464523430436032, 0.9181818181818182, 'X[1] <= 120.0\nsquared_error = 0.684\nsamples = 3744\nvalue = 11.536'),
#  Text(0.007806548745322451, 0.9, 'X[56] <= 0.455\nsquared_error = 30.442\nsamples = 2\nvalue = 5.517'),
#  Text(0.007766214566409054, 0.8818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.035'),
#  Text(0.007846882924235849, 0.8818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.04148391986339819, 0.9, 'X[34] <= 2.154\nsquared_error = 0.649\nsamples = 3742\nvalue = 11.539'),
#  Text(0.007927551282062644, 0.8818181818181818, 'X[48] <= 0.982\nsquared_error = 2.021\nsamples = 236\nvalue = 11.111'),
#  Text(0.007246276252296985, 0.8636363636363636, 'X[45] <= 0.979\nsquared_error = 1.525\nsamples = 231\nvalue = 11.162'),
#  Text(0.006125731266246053, 0.8454545454545455, 'X[11] <= 1.5\nsquared_error = 1.006\nsamples = 225\nvalue = 11.205'),
#  Text(0.004247648904364767, 0.8272727272727273, 'X[49] <= 0.983\nsquared_error = 0.433\nsamples = 212\nvalue = 11.265'),
#  Text(0.0025871283748486852, 0.8090909090909091, 'X[46] <= 0.205\nsquared_error = 0.405\nsamples = 209\nvalue = 11.284'),
#  Text(0.0007411405375336811, 0.7909090909090909, 'X[42] <= -2.5\nsquared_error = 0.542\nsamples = 44\nvalue = 11.03'),
#  Text(0.00034284052076387974, 0.7727272727272727, 'X[54] <= 0.544\nsquared_error = 0.399\nsamples = 9\nvalue = 10.372'),
#  Text(0.0003025063418504821, 0.7545454545454545, 'X[60] <= 0.422\nsquared_error = 0.154\nsamples = 8\nvalue = 10.553'),
#  Text(0.00016133671565359047, 0.7363636363636363, 'X[21] <= 1.5\nsquared_error = 0.059\nsamples = 5\nvalue = 10.801'),
#  Text(8.066835782679523e-05, 0.7181818181818181, 'X[62] <= 0.466\nsquared_error = 0.004\nsamples = 2\nvalue = 10.53'),
#  Text(4.033417891339762e-05, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.463'),
#  Text(0.00012100253674019284, 0.7, 'squared_error = -0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.00024200507348038567, 0.7181818181818181, 'X[60] <= 0.13\nsquared_error = 0.013\nsamples = 3\nvalue = 10.982'),
#  Text(0.00020167089456698807, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.0002823392523937833, 0.7, 'X[61] <= 0.583\nsquared_error = 0.0\nsamples = 2\nvalue = 11.063'),
#  Text(0.00024200507348038567, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.043'),
#  Text(0.00032267343130718093, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.00044367596804737374, 0.7363636363636363, 'X[58] <= 0.837\nsquared_error = 0.039\nsamples = 3\nvalue = 10.14'),
#  Text(0.00040334178913397614, 0.7181818181818181, 'X[44] <= 0.341\nsquared_error = 0.012\nsamples = 2\nvalue = 10.015'),
#  Text(0.00036300761022057854, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.00044367596804737374, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 9.903'),
#  Text(0.00048401014696077135, 0.7181818181818181, 'squared_error = -0.0\nsamples = 1\nvalue = 10.389'),
#  Text(0.00038317469967727734, 0.7545454545454545, 'squared_error = -0.0\nsamples = 1\nvalue = 8.923'),
#  Text(0.0011394405543034827, 0.7727272727272727, 'X[60] <= 0.433\nsquared_error = 0.439\nsamples = 35\nvalue = 11.199'),
#  Text(0.0008066835782679523, 0.7545454545454545, 'X[54] <= 0.772\nsquared_error = 0.411\nsamples = 13\nvalue = 10.71'),
#  Text(0.0006453468626143619, 0.7363636363636363, 'X[46] <= 0.098\nsquared_error = 0.175\nsamples = 7\nvalue = 11.112'),
#  Text(0.0005646785047875666, 0.7181818181818181, 'X[52] <= 0.075\nsquared_error = 0.088\nsamples = 4\nvalue = 11.414'),
#  Text(0.000524344325874169, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 11.918'),
#  Text(0.0006050126837009642, 0.7, 'X[62] <= 0.576\nsquared_error = 0.004\nsamples = 3\nvalue = 11.245'),
#  Text(0.0005646785047875666, 0.6818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 11.29'),
#  Text(0.0006453468626143619, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.0007260152204411571, 0.7181818181818181, 'X[52] <= 0.294\nsquared_error = 0.008\nsamples = 3\nvalue = 10.71'),
#  Text(0.0006856810415277595, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.0007663493993545547, 0.7, 'X[47] <= 0.335\nsquared_error = 0.003\nsamples = 2\nvalue = 10.767'),
#  Text(0.0007260152204411571, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 10.714'),
#  Text(0.0008066835782679523, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.0009680202939215427, 0.7363636363636363, 'X[5] <= 0.5\nsquared_error = 0.279\nsamples = 6\nvalue = 10.242'),
#  Text(0.0008873519360947475, 0.7181818181818181, 'X[52] <= 0.139\nsquared_error = 0.033\nsamples = 4\nvalue = 9.887'),
#  Text(0.0008470177571813499, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.0009276861150081451, 0.7, 'X[47] <= 0.536\nsquared_error = 0.011\nsamples = 3\nvalue = 9.978'),
#  Text(0.0008873519360947475, 0.6818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 9.903'),
#  Text(0.0009680202939215427, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.001048688651748338, 0.7181818181818181, 'X[8] <= 1.5\nsquared_error = 0.017\nsamples = 2\nvalue = 10.951'),
#  Text(0.0010083544728349404, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.0010890228306617356, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.001472197530339013, 0.7545454545454545, 'X[56] <= 0.081\nsquared_error = 0.231\nsamples = 22\nvalue = 11.488'),
#  Text(0.001250359546315326, 0.7363636363636363, 'X[50] <= 0.636\nsquared_error = 0.004\nsamples = 3\nvalue = 10.627'),
#  Text(0.0012100253674019283, 0.7181818181818181, 'X[54] <= 0.438\nsquared_error = 0.0\nsamples = 2\nvalue = 10.584'),
#  Text(0.0011696911884885308, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.001250359546315326, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.571'),
#  Text(0.0012906937252287237, 0.7181818181818181, 'squared_error = -0.0\nsamples = 1\nvalue = 10.714'),
#  Text(0.0016940355143626998, 0.7363636363636363, 'X[9] <= 1.5\nsquared_error = 0.131\nsamples = 19\nvalue = 11.624'),
#  Text(0.001472197530339013, 0.7181818181818181, 'X[59] <= 0.505\nsquared_error = 0.058\nsamples = 9\nvalue = 11.863'),
#  Text(0.0013310279041421212, 0.7, 'X[56] <= 0.408\nsquared_error = 0.004\nsamples = 6\nvalue = 11.718'),
#  Text(0.001250359546315326, 0.6818181818181818, 'X[52] <= 0.33\nsquared_error = 0.002\nsamples = 3\nvalue = 11.666'),
#  Text(0.0012100253674019283, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.0012906937252287237, 0.6636363636363637, 'squared_error = 0.0\nsamples = 2\nvalue = 11.695'),
#  Text(0.0014116962619689164, 0.6818181818181818, 'X[50] <= 0.372\nsquared_error = 0.001\nsamples = 3\nvalue = 11.77'),
#  Text(0.001371362083055519, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.0014520304408823142, 0.6636363636363637, 'X[29] <= 0.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.748'),
#  Text(0.0014116962619689164, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.0014923646197957116, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.76'),
#  Text(0.0016133671565359046, 0.7, 'X[21] <= 1.5\nsquared_error = 0.039\nsamples = 3\nvalue = 12.152'),
#  Text(0.0015730329776225069, 0.6818181818181818, 'X[48] <= 0.35\nsquared_error = 0.001\nsamples = 2\nvalue = 12.013'),
#  Text(0.0015326987987091094, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 12.044'),
#  Text(0.0016133671565359046, 0.6636363636363637, 'squared_error = -0.0\nsamples = 1\nvalue = 11.983'),
#  Text(0.0016537013354493023, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 12.429'),
#  Text(0.0019158734983863866, 0.7181818181818181, 'X[46] <= 0.076\nsquared_error = 0.1\nsamples = 10\nvalue = 11.409'),
#  Text(0.001774703872189495, 0.7, 'X[56] <= 0.379\nsquared_error = 0.061\nsamples = 3\nvalue = 11.778'),
#  Text(0.0017343696932760975, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 12.128'),
#  Text(0.0018150380511028927, 0.6818181818181818, 'X[2] <= 1982.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.604'),
#  Text(0.001774703872189495, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.0018553722300162902, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.599'),
#  Text(0.0020570431245832783, 0.7, 'X[53] <= 0.573\nsquared_error = 0.033\nsamples = 7\nvalue = 11.25'),
#  Text(0.001976374766756483, 0.6818181818181818, 'X[57] <= 0.744\nsquared_error = 0.027\nsamples = 4\nvalue = 11.142'),
#  Text(0.0019360405878430854, 0.6636363636363637, 'X[46] <= 0.093\nsquared_error = 0.005\nsamples = 3\nvalue = 11.053'),
#  Text(0.001895706408929688, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.001976374766756483, 0.6454545454545455, 'squared_error = 0.0\nsamples = 2\nvalue = 11.002'),
#  Text(0.002016708945669881, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.0021377114824100737, 0.6818181818181818, 'X[61] <= 0.498\nsquared_error = 0.004\nsamples = 3\nvalue = 11.395'),
#  Text(0.002097377303496676, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.314'),
#  Text(0.0021780456613234712, 0.6636363636363637, 'X[37] <= 1.5\nsquared_error = 0.001\nsamples = 2\nvalue = 11.435'),
#  Text(0.0021377114824100737, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.0022183798402368687, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.004433116212163689, 0.7909090909090909, 'X[55] <= 0.469\nsquared_error = 0.347\nsamples = 165\nvalue = 11.352'),
#  Text(0.003119399706100121, 0.7727272727272727, 'X[4] <= 1.5\nsquared_error = 0.242\nsamples = 66\nvalue = 11.517'),
#  Text(0.0026318051740991943, 0.7545454545454545, 'X[1] <= 1063.5\nsquared_error = 0.361\nsamples = 14\nvalue = 11.143'),
#  Text(0.002520886182087351, 0.7363636363636363, 'X[20] <= 1.5\nsquared_error = 0.287\nsamples = 9\nvalue = 11.449'),
#  Text(0.0024200507348038566, 0.7181818181818181, 'X[42] <= 1.5\nsquared_error = 0.072\nsamples = 7\nvalue = 11.696'),
#  Text(0.0023393823769770616, 0.7, 'X[49] <= 0.637\nsquared_error = 0.058\nsamples = 3\nvalue = 11.945'),
#  Text(0.002299048198063664, 0.6818181818181818, 'X[53] <= 0.601\nsquared_error = 0.002\nsamples = 2\nvalue = 12.114'),
#  Text(0.002258714019150266, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 12.073'),
#  Text(0.0023393823769770616, 0.6636363636363637, 'squared_error = -0.0\nsamples = 1\nvalue = 12.155'),
#  Text(0.002379716555890459, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.002500719092630652, 0.7, 'X[50] <= 0.248\nsquared_error = 0.001\nsamples = 4\nvalue = 11.51'),
#  Text(0.0024603849137172546, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.562'),
#  Text(0.0025410532715440495, 0.6818181818181818, 'X[62] <= 0.397\nsquared_error = 0.0\nsamples = 3\nvalue = 11.492'),
#  Text(0.002500719092630652, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.0025813874504574475, 0.6636363636363637, 'X[2] <= 1999.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.508'),
#  Text(0.0025410532715440495, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.002621721629370845, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.503'),
#  Text(0.002621721629370845, 0.7181818181818181, 'X[8] <= 3.5\nsquared_error = 0.076\nsamples = 2\nvalue = 10.584'),
#  Text(0.0025813874504574475, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.0026620558082842425, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 10.859'),
#  Text(0.002742724166111038, 0.7363636363636363, 'X[50] <= 0.293\nsquared_error = 0.021\nsamples = 5\nvalue = 10.592'),
#  Text(0.00270238998719764, 0.7181818181818181, 'squared_error = 0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.0027830583450244354, 0.7181818181818181, 'X[49] <= 0.413\nsquared_error = 0.002\nsamples = 4\nvalue = 10.662'),
#  Text(0.002742724166111038, 0.7, 'X[44] <= 0.606\nsquared_error = 0.0\nsamples = 3\nvalue = 10.684'),
#  Text(0.00270238998719764, 0.6818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 10.669'),
#  Text(0.0027830583450244354, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 10.714'),
#  Text(0.002823392523937833, 0.7, 'squared_error = -0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.003606994238101048, 0.7545454545454545, 'X[2] <= 1955.0\nsquared_error = 0.163\nsamples = 52\nvalue = 11.618'),
#  Text(0.0031763165894300623, 0.7363636363636363, 'X[53] <= 0.821\nsquared_error = 0.14\nsamples = 12\nvalue = 11.946'),
#  Text(0.00304523050796152, 0.7181818181818181, 'X[44] <= 0.244\nsquared_error = 0.051\nsamples = 9\nvalue = 12.121'),
#  Text(0.0029040608817646283, 0.7, 'X[54] <= 0.062\nsquared_error = 0.002\nsamples = 3\nvalue = 11.895'),
#  Text(0.002863726702851231, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.951'),
#  Text(0.002944395060678026, 0.6818181818181818, 'X[60] <= 0.447\nsquared_error = 0.0\nsamples = 2\nvalue = 11.867'),
#  Text(0.0029040608817646283, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.884'),
#  Text(0.0029847292395914233, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.0031864001341584116, 0.7, 'X[9] <= 1.5\nsquared_error = 0.037\nsamples = 6\nvalue = 12.233'),
#  Text(0.0031460659552450137, 0.6818181818181818, 'X[42] <= -2.5\nsquared_error = 0.01\nsamples = 5\nvalue = 12.31'),
#  Text(0.0030653975974182187, 0.6636363636363637, 'X[5] <= 0.5\nsquared_error = 0.003\nsamples = 2\nvalue = 12.205'),
#  Text(0.0030250634185048212, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 12.255'),
#  Text(0.003105731776331616, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 12.155'),
#  Text(0.003226734313071809, 0.6636363636363637, 'X[44] <= 0.321\nsquared_error = 0.002\nsamples = 3\nvalue = 12.38'),
#  Text(0.0031864001341584116, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 12.324'),
#  Text(0.0032670684919852066, 0.6454545454545455, 'X[8] <= 2.5\nsquared_error = 0.0\nsamples = 2\nvalue = 12.409'),
#  Text(0.003226734313071809, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 12.429'),
#  Text(0.0033074026708986046, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 12.388'),
#  Text(0.003226734313071809, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.0033074026708986046, 0.7181818181818181, 'X[61] <= 0.301\nsquared_error = 0.042\nsamples = 3\nvalue = 11.424'),
#  Text(0.0032670684919852066, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.003347736849812002, 0.7, 'X[46] <= 0.519\nsquared_error = 0.009\nsamples = 2\nvalue = 11.557'),
#  Text(0.0033074026708986046, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.653'),
#  Text(0.0033880710287253995, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.004037671886772034, 0.7363636363636363, 'X[61] <= 0.137\nsquared_error = 0.128\nsamples = 40\nvalue = 11.519'),
#  Text(0.0035090735654655925, 0.7181818181818181, 'X[53] <= 0.16\nsquared_error = 0.139\nsamples = 6\nvalue = 11.99'),
#  Text(0.003468739386552195, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 12.766'),
#  Text(0.00354940774437899, 0.7, 'X[58] <= 0.092\nsquared_error = 0.023\nsamples = 5\nvalue = 11.835'),
#  Text(0.003468739386552195, 0.6818181818181818, 'X[53] <= 0.442\nsquared_error = 0.001\nsamples = 2\nvalue = 11.67'),
#  Text(0.003428405207638797, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.644'),
#  Text(0.0035090735654655925, 0.6636363636363637, 'squared_error = -0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.0036300761022057854, 0.6818181818181818, 'X[61] <= 0.127\nsquared_error = 0.007\nsamples = 3\nvalue = 11.946'),
#  Text(0.0035897419232923874, 0.6636363636363637, 'X[58] <= 0.725\nsquared_error = 0.002\nsamples = 2\nvalue = 11.997'),
#  Text(0.00354940774437899, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.951'),
#  Text(0.0036300761022057854, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 12.044'),
#  Text(0.003670410281119183, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.842'),
#  Text(0.004566270208078475, 0.7181818181818181, 'X[59] <= 0.857\nsquared_error = 0.079\nsamples = 34\nvalue = 11.436'),
#  Text(0.004408399710925255, 0.7, 'X[57] <= 0.968\nsquared_error = 0.069\nsamples = 30\nvalue = 11.388'),
#  Text(0.004213661253359007, 0.6818181818181818, 'X[49] <= 0.674\nsquared_error = 0.057\nsamples = 28\nvalue = 11.421'),
#  Text(0.003945186874966704, 0.6636363636363637, 'X[60] <= 0.902\nsquared_error = 0.031\nsamples = 20\nvalue = 11.348'),
#  Text(0.0037107444600325804, 0.6454545454545455, 'X[53] <= 0.617\nsquared_error = 0.023\nsamples = 17\nvalue = 11.308'),
#  Text(0.003443530524731321, 0.6272727272727273, 'X[47] <= 0.231\nsquared_error = 0.017\nsamples = 10\nvalue = 11.387'),
#  Text(0.003332611532719478, 0.6090909090909091, 'X[60] <= 0.104\nsquared_error = 0.001\nsamples = 2\nvalue = 11.191'),
#  Text(0.00329227735380608, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.0033729457116328755, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.0035544495167431646, 0.6090909090909091, 'X[51] <= 0.209\nsquared_error = 0.009\nsamples = 8\nvalue = 11.436'),
#  Text(0.003453614069459671, 0.5909090909090909, 'X[9] <= 1.5\nsquared_error = 0.005\nsamples = 2\nvalue = 11.582'),
#  Text(0.003413279890546273, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.0034939482483730684, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.65'),
#  Text(0.003655284964026659, 0.5909090909090909, 'X[45] <= 0.807\nsquared_error = 0.002\nsamples = 6\nvalue = 11.388'),
#  Text(0.0035746166061998634, 0.5727272727272728, 'X[60] <= 0.34\nsquared_error = 0.001\nsamples = 4\nvalue = 11.365'),
#  Text(0.003534282427286466, 0.5545454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.0036149507851132613, 0.5545454545454546, 'X[4] <= 2.5\nsquared_error = 0.0\nsamples = 3\nvalue = 11.35'),
#  Text(0.0035746166061998634, 0.5363636363636364, 'X[46] <= 0.487\nsquared_error = 0.0\nsamples = 2\nvalue = 11.35'),
#  Text(0.003534282427286466, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.0036149507851132613, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.003655284964026659, 0.5363636363636364, 'squared_error = -0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.003735953321853454, 0.5727272727272728, 'X[62] <= 0.469\nsquared_error = 0.001\nsamples = 2\nvalue = 11.435'),
#  Text(0.0036956191429400563, 0.5545454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.0037762875007668517, 0.5545454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.00397795839533384, 0.6272727272727273, 'X[48] <= 0.046\nsquared_error = 0.009\nsamples = 7\nvalue = 11.194'),
#  Text(0.003937624216420442, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.396'),
#  Text(0.004018292574247237, 0.6090909090909091, 'X[51] <= 0.66\nsquared_error = 0.002\nsamples = 6\nvalue = 11.16'),
#  Text(0.003937624216420442, 0.5909090909090909, 'X[37] <= 1.5\nsquared_error = 0.001\nsamples = 4\nvalue = 11.134'),
#  Text(0.0038972900375070446, 0.5727272727272728, 'X[58] <= 0.442\nsquared_error = 0.0\nsamples = 3\nvalue = 11.151'),
#  Text(0.0038569558585936467, 0.5545454545454546, 'X[48] <= 0.182\nsquared_error = 0.0\nsamples = 2\nvalue = 11.156'),
#  Text(0.0038166216796802492, 0.5363636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.0038972900375070446, 0.5363636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.003937624216420442, 0.5545454545454546, 'squared_error = -0.0\nsamples = 1\nvalue = 11.142'),
#  Text(0.00397795839533384, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.004098960932074032, 0.5909090909090909, 'X[55] <= 0.236\nsquared_error = 0.0\nsamples = 2\nvalue = 11.212'),
#  Text(0.004058626753160635, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.0041392951109874305, 0.5727272727272728, 'squared_error = -0.0\nsamples = 1\nvalue = 11.198'),
#  Text(0.004179629289900828, 0.6454545454545455, 'X[43] <= 0.344\nsquared_error = 0.013\nsamples = 3\nvalue = 11.577'),
#  Text(0.0041392951109874305, 0.6272727272727273, 'X[45] <= 0.666\nsquared_error = 0.0\nsamples = 2\nvalue = 11.498'),
#  Text(0.004098960932074032, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.482'),
#  Text(0.004179629289900828, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.0042199634688142255, 0.6272727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.00448213563175131, 0.6636363636363637, 'X[60] <= 0.773\nsquared_error = 0.075\nsamples = 8\nvalue = 11.604'),
#  Text(0.0043813001844678155, 0.6454545454545455, 'X[15] <= 1.5\nsquared_error = 0.029\nsamples = 6\nvalue = 11.736'),
#  Text(0.0043006318266410205, 0.6272727272727273, 'X[52] <= 0.835\nsquared_error = 0.006\nsamples = 3\nvalue = 11.895'),
#  Text(0.004260297647727623, 0.6090909090909091, 'X[62] <= 0.466\nsquared_error = 0.001\nsamples = 2\nvalue = 11.948'),
#  Text(0.0042199634688142255, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.918'),
#  Text(0.0043006318266410205, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.977'),
#  Text(0.004340966005554418, 0.6090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.791'),
#  Text(0.004461968542294611, 0.6272727272727273, 'X[45] <= 0.397\nsquared_error = 0.002\nsamples = 3\nvalue = 11.576'),
#  Text(0.004421634363381214, 0.6090909090909091, 'X[61] <= 0.511\nsquared_error = 0.0\nsamples = 2\nvalue = 11.608'),
#  Text(0.0043813001844678155, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.004461968542294611, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.004502302721208009, 0.6090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.004582971079034804, 0.6454545454545455, 'X[43] <= 0.296\nsquared_error = 0.003\nsamples = 2\nvalue = 11.207'),
#  Text(0.004542636900121406, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.258'),
#  Text(0.004623305257948201, 0.6272727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.0046031381684915025, 0.6818181818181818, 'X[29] <= 0.5\nsquared_error = 0.023\nsamples = 2\nvalue = 10.931'),
#  Text(0.004562803989578105, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 10.779'),
#  Text(0.0046434723474049, 0.6636363636363637, 'squared_error = -0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.004724140705231696, 0.7, 'X[38] <= 1.5\nsquared_error = 0.01\nsamples = 4\nvalue = 11.793'),
#  Text(0.0046838065263182975, 0.6818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 11.695'),
#  Text(0.004764474884145093, 0.6818181818181818, 'X[60] <= 0.485\nsquared_error = 0.002\nsamples = 2\nvalue = 11.891'),
#  Text(0.004724140705231696, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.004804809063058491, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 11.932'),
#  Text(0.0057468327182272575, 0.7727272727272727, 'X[55] <= 0.5\nsquared_error = 0.386\nsamples = 99\nvalue = 11.242'),
#  Text(0.005167816673279069, 0.7545454545454545, 'X[56] <= 0.672\nsquared_error = 0.725\nsamples = 12\nvalue = 10.69'),
#  Text(0.005127482494365672, 0.7363636363636363, 'X[48] <= 0.489\nsquared_error = 0.277\nsamples = 11\nvalue = 10.897'),
#  Text(0.004966145778712081, 0.7181818181818181, 'X[58] <= 0.386\nsquared_error = 0.055\nsamples = 6\nvalue = 11.292'),
#  Text(0.004885477420885286, 0.7, 'X[59] <= 0.822\nsquared_error = 0.022\nsamples = 2\nvalue = 11.008'),
#  Text(0.004845143241971888, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 10.859'),
#  Text(0.004925811599798683, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.005046814136538877, 0.7, 'X[47] <= 0.856\nsquared_error = 0.01\nsamples = 4\nvalue = 11.434'),
#  Text(0.005006479957625479, 0.6818181818181818, 'X[46] <= 0.594\nsquared_error = 0.0\nsamples = 3\nvalue = 11.375'),
#  Text(0.004966145778712081, 0.6636363636363637, 'X[62] <= 0.396\nsquared_error = 0.0\nsamples = 2\nvalue = 11.388'),
#  Text(0.004925811599798683, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.396'),
#  Text(0.005006479957625479, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.379'),
#  Text(0.005046814136538877, 0.6636363636363637, 'squared_error = -0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.005087148315452274, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.0052888192100192626, 0.7181818181818181, 'X[47] <= 0.594\nsquared_error = 0.132\nsamples = 5\nvalue = 10.424'),
#  Text(0.005208150852192467, 0.7, 'X[8] <= 3.5\nsquared_error = 0.041\nsamples = 2\nvalue = 10.799'),
#  Text(0.005167816673279069, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.005248485031105864, 0.6818181818181818, 'squared_error = -0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.0053694875678460575, 0.7, 'X[47] <= 0.827\nsquared_error = 0.037\nsamples = 3\nvalue = 10.174'),
#  Text(0.00532915338893266, 0.6818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 10.309'),
#  Text(0.005409821746759455, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 9.903'),
#  Text(0.005208150852192467, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 8.412'),
#  Text(0.006325848763175446, 0.7545454545454545, 'X[58] <= 0.063\nsquared_error = 0.291\nsamples = 87\nvalue = 11.318'),
#  Text(0.005571158462413045, 0.7363636363636363, 'X[48] <= 0.329\nsquared_error = 0.32\nsamples = 5\nvalue = 12.031'),
#  Text(0.00549049010458625, 0.7181818181818181, 'X[48] <= 0.239\nsquared_error = 0.005\nsamples = 3\nvalue = 12.479'),
#  Text(0.0054501559256728525, 0.7, 'squared_error = -0.0\nsamples = 2\nvalue = 12.429'),
#  Text(0.0055308242834996475, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 12.578'),
#  Text(0.005651826820239841, 0.7181818181818181, 'X[50] <= 0.689\nsquared_error = 0.041\nsamples = 2\nvalue = 11.359'),
#  Text(0.005611492641326443, 0.7, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.005692160999153238, 0.7, 'squared_error = -0.0\nsamples = 1\nvalue = 11.562'),
#  Text(0.007080539063937847, 0.7363636363636363, 'X[50] <= 0.503\nsquared_error = 0.257\nsamples = 82\nvalue = 11.274'),
#  Text(0.00623793285757515, 0.7181818181818181, 'X[55] <= 0.941\nsquared_error = 0.225\nsamples = 43\nvalue = 11.094'),
#  Text(0.005772829356980033, 0.7, 'X[2] <= 1972.5\nsquared_error = 0.179\nsamples = 36\nvalue = 11.003'),
#  Text(0.005503094535496687, 0.6818181818181818, 'X[59] <= 0.71\nsquared_error = 0.142\nsamples = 15\nvalue = 10.741'),
#  Text(0.005311507185658048, 0.6636363636363637, 'X[52] <= 0.475\nsquared_error = 0.108\nsamples = 9\nvalue = 10.524'),
#  Text(0.005210671738374554, 0.6454545454545455, 'X[2] <= 1960.0\nsquared_error = 0.006\nsamples = 4\nvalue = 10.263'),
#  Text(0.005170337559461157, 0.6272727272727273, 'squared_error = 0.0\nsamples = 3\nvalue = 10.309'),
#  Text(0.005251005917287952, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.005412342632941543, 0.6454545454545455, 'X[50] <= 0.279\nsquared_error = 0.092\nsamples = 5\nvalue = 10.733'),
#  Text(0.005331674275114747, 0.6272727272727273, 'X[54] <= 0.558\nsquared_error = 0.018\nsamples = 3\nvalue = 10.501'),
#  Text(0.005291340096201349, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 10.309'),
#  Text(0.005372008454028145, 0.6090909090909091, 'X[43] <= 0.672\nsquared_error = 0.0\nsamples = 2\nvalue = 10.597'),
#  Text(0.005331674275114747, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.005412342632941543, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.005493010990768338, 0.6272727272727273, 'X[60] <= 0.644\nsquared_error = 0.0\nsamples = 2\nvalue = 11.082'),
#  Text(0.00545267681185494, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.005533345169681735, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.005694681885335326, 0.6636363636363637, 'X[44] <= 0.407\nsquared_error = 0.015\nsamples = 6\nvalue = 11.067'),
#  Text(0.00561401352750853, 0.6454545454545455, 'X[48] <= 0.133\nsquared_error = 0.005\nsamples = 3\nvalue = 10.954'),
#  Text(0.005573679348595133, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 10.859'),
#  Text(0.0056543477064219284, 0.6272727272727273, 'squared_error = 0.0\nsamples = 2\nvalue = 11.002'),
#  Text(0.005775350243162121, 0.6454545454545455, 'X[59] <= 0.845\nsquared_error = 0.001\nsamples = 3\nvalue = 11.179'),
#  Text(0.005735016064248723, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.005815684422075518, 0.6272727272727273, 'squared_error = -0.0\nsamples = 2\nvalue = 11.156'),
#  Text(0.00604256417846338, 0.6818181818181818, 'X[59] <= 0.142\nsquared_error = 0.122\nsamples = 21\nvalue = 11.19'),
#  Text(0.005896352779902313, 0.6636363636363637, 'X[9] <= 1.5\nsquared_error = 0.004\nsamples = 3\nvalue = 10.508'),
#  Text(0.005856018600988916, 0.6454545454545455, 'squared_error = 0.0\nsamples = 2\nvalue = 10.463'),
#  Text(0.005936686958815711, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.006188775577024446, 0.6636363636363637, 'X[45] <= 0.025\nsquared_error = 0.051\nsamples = 18\nvalue = 11.304'),
#  Text(0.006017355316642507, 0.6454545454545455, 'X[9] <= 1.5\nsquared_error = 0.002\nsamples = 2\nvalue = 11.735'),
#  Text(0.005977021137729109, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.006057689495555904, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.006360195837406386, 0.6454545454545455, 'X[52] <= 0.405\nsquared_error = 0.031\nsamples = 16\nvalue = 11.25'),
#  Text(0.006138357853382699, 0.6272727272727273, 'X[53] <= 0.473\nsquared_error = 0.021\nsamples = 5\nvalue = 11.437'),
#  Text(0.006057689495555904, 0.6090909090909091, 'X[2] <= 1982.5\nsquared_error = 0.004\nsamples = 2\nvalue = 11.288'),
#  Text(0.006017355316642507, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.006098023674469302, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.006219026211209494, 0.6090909090909091, 'X[38] <= 1.5\nsquared_error = 0.008\nsamples = 3\nvalue = 11.537'),
#  Text(0.006178692032296097, 0.5909090909090909, 'X[61] <= 0.242\nsquared_error = 0.002\nsamples = 2\nvalue = 11.479'),
#  Text(0.006138357853382699, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.518'),
#  Text(0.006219026211209494, 0.5727272727272728, 'squared_error = -0.0\nsamples = 1\nvalue = 11.44'),
#  Text(0.006259360390122893, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.653'),
#  Text(0.006582033821430073, 0.6272727272727273, 'X[56] <= 0.537\nsquared_error = 0.012\nsamples = 11\nvalue = 11.164'),
#  Text(0.006420697105776483, 0.6090909090909091, 'X[47] <= 0.295\nsquared_error = 0.007\nsamples = 6\nvalue = 11.242'),
#  Text(0.006340028747949688, 0.5909090909090909, 'X[20] <= 1.5\nsquared_error = 0.001\nsamples = 4\nvalue = 11.192'),
#  Text(0.00629969456903629, 0.5727272727272728, 'squared_error = 0.0\nsamples = 2\nvalue = 11.225'),
#  Text(0.006380362926863085, 0.5727272727272728, 'X[58] <= 0.472\nsquared_error = 0.0\nsamples = 2\nvalue = 11.159'),
#  Text(0.006340028747949688, 0.5545454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 11.162'),
#  Text(0.006420697105776483, 0.5545454545454546, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.0065013654636032776, 0.5909090909090909, 'X[62] <= 0.451\nsquared_error = 0.003\nsamples = 2\nvalue = 11.343'),
#  Text(0.00646103128468988, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.396'),
#  Text(0.006541699642516676, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.006743370537083663, 0.6090909090909091, 'X[17] <= 1.5\nsquared_error = 0.002\nsamples = 5\nvalue = 11.07'),
#  Text(0.006662702179256868, 0.5909090909090909, 'X[2] <= 1982.5\nsquared_error = 0.001\nsamples = 3\nvalue = 11.102'),
#  Text(0.006622368000343471, 0.5727272727272728, 'X[48] <= 0.382\nsquared_error = 0.0\nsamples = 2\nvalue = 11.082'),
#  Text(0.006582033821430073, 0.5545454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.006662702179256868, 0.5545454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.006703036358170266, 0.5727272727272728, 'squared_error = -0.0\nsamples = 1\nvalue = 11.142'),
#  Text(0.006824038894910458, 0.5909090909090909, 'X[60] <= 0.473\nsquared_error = 0.0\nsamples = 2\nvalue = 11.023'),
#  Text(0.006783704715997061, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.043'),
#  Text(0.006864373073823857, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.006703036358170266, 0.7, 'X[45] <= 0.109\nsquared_error = 0.196\nsamples = 7\nvalue = 11.563'),
#  Text(0.006662702179256868, 0.6818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.006743370537083663, 0.6818181818181818, 'X[46] <= 0.274\nsquared_error = 0.047\nsamples = 6\nvalue = 11.724'),
#  Text(0.006703036358170266, 0.6636363636363637, 'squared_error = 0.0\nsamples = 1\nvalue = 12.155'),
#  Text(0.006783704715997061, 0.6636363636363637, 'X[61] <= 0.526\nsquared_error = 0.012\nsamples = 5\nvalue = 11.638'),
#  Text(0.006703036358170266, 0.6454545454545455, 'X[51] <= 0.478\nsquared_error = 0.0\nsamples = 2\nvalue = 11.756'),
#  Text(0.006662702179256868, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.006743370537083663, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.006864373073823857, 0.6454545454545455, 'X[54] <= 0.477\nsquared_error = 0.005\nsamples = 3\nvalue = 11.559'),
#  Text(0.006824038894910458, 0.6272727272727273, 'squared_error = 0.0\nsamples = 2\nvalue = 11.608'),
#  Text(0.006904707252737254, 0.6272727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.007923145270300544, 0.7181818181818181, 'X[38] <= 1.5\nsquared_error = 0.217\nsamples = 39\nvalue = 11.473'),
#  Text(0.007550054115351616, 0.7, 'X[57] <= 0.381\nsquared_error = 0.168\nsamples = 30\nvalue = 11.352'),
#  Text(0.007297965497142881, 0.6818181818181818, 'X[1] <= 1725.0\nsquared_error = 0.117\nsamples = 14\nvalue = 11.137'),
#  Text(0.007126545236760941, 0.6636363636363637, 'X[48] <= 0.177\nsquared_error = 0.05\nsamples = 11\nvalue = 10.994'),
#  Text(0.007025709789477447, 0.6454545454545455, 'X[48] <= 0.131\nsquared_error = 0.001\nsamples = 3\nvalue = 11.26'),
#  Text(0.006985375610564049, 0.6272727272727273, 'X[34] <= 1.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.277'),
#  Text(0.006945041431650652, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.007025709789477447, 0.6090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.264'),
#  Text(0.007066043968390844, 0.6272727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.007227380684044435, 0.6454545454545455, 'X[52] <= 0.139\nsquared_error = 0.032\nsamples = 8\nvalue = 10.894'),
#  Text(0.00714671232621764, 0.6272727272727273, 'X[53] <= 0.84\nsquared_error = 0.009\nsamples = 3\nvalue = 11.093'),
#  Text(0.007106378147304242, 0.6090909090909091, 'X[57] <= 0.211\nsquared_error = 0.001\nsamples = 2\nvalue = 11.026'),
#  Text(0.007066043968390844, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.00714671232621764, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 11.051'),
#  Text(0.007187046505131038, 0.6090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.00730804904187123, 0.6272727272727273, 'X[51] <= 0.524\nsquared_error = 0.008\nsamples = 5\nvalue = 10.775'),
#  Text(0.007267714862957833, 0.6090909090909091, 'X[44] <= 0.533\nsquared_error = 0.0\nsamples = 4\nvalue = 10.82'),
#  Text(0.007227380684044435, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.00730804904187123, 0.5909090909090909, 'squared_error = 0.0\nsamples = 3\nvalue = 10.82'),
#  Text(0.0073483832207846276, 0.6090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.007469385757524821, 0.6636363636363637, 'X[28] <= 0.5\nsquared_error = 0.012\nsamples = 3\nvalue = 11.661'),
#  Text(0.007429051578611423, 0.6454545454545455, 'X[60] <= 0.715\nsquared_error = 0.002\nsamples = 2\nvalue = 11.735'),
#  Text(0.007388717399698025, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.007469385757524821, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.007509719936438218, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.007802142733560351, 0.6818181818181818, 'X[46] <= 0.91\nsquared_error = 0.137\nsamples = 16\nvalue = 11.541'),
#  Text(0.007691223741548507, 0.6636363636363637, 'X[48] <= 0.425\nsquared_error = 0.061\nsamples = 14\nvalue = 11.647'),
#  Text(0.007590388294265013, 0.6454545454545455, 'X[62] <= 0.9\nsquared_error = 0.027\nsamples = 6\nvalue = 11.85'),
#  Text(0.007550054115351616, 0.6272727272727273, 'X[1] <= 1400.0\nsquared_error = 0.005\nsamples = 5\nvalue = 11.917'),
#  Text(0.007509719936438218, 0.6090909090909091, 'X[50] <= 0.798\nsquared_error = 0.001\nsamples = 4\nvalue = 11.947'),
#  Text(0.007469385757524821, 0.5909090909090909, 'squared_error = 0.0\nsamples = 2\nvalue = 11.983'),
#  Text(0.007550054115351616, 0.5909090909090909, 'squared_error = -0.0\nsamples = 2\nvalue = 11.912'),
#  Text(0.007590388294265013, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.798'),
#  Text(0.007630722473178411, 0.6272727272727273, 'squared_error = -0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.007792059188832002, 0.6454545454545455, 'X[51] <= 0.706\nsquared_error = 0.032\nsamples = 8\nvalue = 11.495'),
#  Text(0.007711390831005207, 0.6272727272727273, 'X[49] <= 0.744\nsquared_error = 0.01\nsamples = 4\nvalue = 11.334'),
#  Text(0.007671056652091808, 0.6090909090909091, 'X[1] <= 1550.0\nsquared_error = 0.001\nsamples = 3\nvalue = 11.388'),
#  Text(0.007630722473178411, 0.5909090909090909, 'X[20] <= 1.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.368'),
#  Text(0.007590388294265013, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.007671056652091808, 0.5727272727272728, 'squared_error = 0.0\nsamples = 1\nvalue = 11.385'),
#  Text(0.007711390831005207, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 11.43'),
#  Text(0.007751725009918604, 0.6090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.17'),
#  Text(0.007872727546658798, 0.6272727272727273, 'X[62] <= 0.747\nsquared_error = 0.003\nsamples = 4\nvalue = 11.656'),
#  Text(0.007832393367745398, 0.6090909090909091, 'X[5] <= 0.5\nsquared_error = 0.001\nsamples = 2\nvalue = 11.703'),
#  Text(0.007792059188832002, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.007872727546658798, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.67'),
#  Text(0.007913061725572195, 0.6090909090909091, 'squared_error = -0.0\nsamples = 2\nvalue = 11.608'),
#  Text(0.007913061725572195, 0.6636363636363637, 'X[52] <= 0.384\nsquared_error = 0.041\nsamples = 2\nvalue = 10.799'),
#  Text(0.007872727546658798, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.007953395904485593, 0.6454545454545455, 'squared_error = -0.0\nsamples = 1\nvalue = 11.002'),
#  Text(0.008296236425249471, 0.7, 'X[50] <= 0.77\nsquared_error = 0.169\nsamples = 9\nvalue = 11.876'),
#  Text(0.00815506679905258, 0.6818181818181818, 'X[49] <= 0.737\nsquared_error = 0.035\nsamples = 5\nvalue = 12.202'),
#  Text(0.008074398441225785, 0.6636363636363637, 'X[60] <= 0.718\nsquared_error = 0.014\nsamples = 3\nvalue = 12.324'),
#  Text(0.008034064262312388, 0.6454545454545455, 'X[52] <= 0.405\nsquared_error = 0.001\nsamples = 2\nvalue = 12.242'),
#  Text(0.00799373008339899, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 12.278'),
#  Text(0.008074398441225785, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 12.206'),
#  Text(0.008114732620139183, 0.6454545454545455, 'squared_error = -0.0\nsamples = 1\nvalue = 12.487'),
#  Text(0.008235735156879375, 0.6636363636363637, 'X[53] <= 0.643\nsquared_error = 0.012\nsamples = 2\nvalue = 12.02'),
#  Text(0.008195400977965978, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.912'),
#  Text(0.008276069335792773, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 12.128'),
#  Text(0.008437406051446363, 0.6818181818181818, 'X[54] <= 0.95\nsquared_error = 0.037\nsamples = 4\nvalue = 11.468'),
#  Text(0.008397071872532965, 0.6636363636363637, 'X[56] <= 0.447\nsquared_error = 0.006\nsamples = 3\nvalue = 11.571'),
#  Text(0.008356737693619568, 0.6454545454545455, 'X[5] <= 0.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.626'),
#  Text(0.00831640351470617, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.008397071872532965, 0.6272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 11.644'),
#  Text(0.008437406051446363, 0.6454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.008477740230359762, 0.6636363636363637, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.005908169433880848, 0.8090909090909091, 'X[45] <= 0.468\nsquared_error = 0.565\nsamples = 3\nvalue = 9.931'),
#  Text(0.005867835254967451, 0.7909090909090909, 'X[59] <= 0.582\nsquared_error = 0.041\nsamples = 2\nvalue = 9.413'),
#  Text(0.0058275010760540525, 0.7727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.616'),
#  Text(0.005908169433880848, 0.7727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.21'),
#  Text(0.005948503612794246, 0.7909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 10.968'),
#  Text(0.008003813628127339, 0.8272727272727273, 'X[51] <= 0.852\nsquared_error = 9.335\nsamples = 13\nvalue = 10.224'),
#  Text(0.007963479449213941, 0.8090909090909091, 'X[62] <= 0.464\nsquared_error = 0.676\nsamples = 12\nvalue = 11.076'),
#  Text(0.007802142733560351, 0.7909090909090909, 'X[56] <= 0.93\nsquared_error = 0.39\nsamples = 5\nvalue = 11.683'),
#  Text(0.007761808554646954, 0.7727272727272727, 'X[58] <= 0.529\nsquared_error = 0.118\nsamples = 4\nvalue = 11.955'),
#  Text(0.007681140196820158, 0.7545454545454545, 'X[38] <= 1.5\nsquared_error = 0.017\nsamples = 2\nvalue = 11.644'),
#  Text(0.00764080601790676, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.007721474375733556, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.007842476912473749, 0.7545454545454545, 'X[50] <= 0.345\nsquared_error = 0.027\nsamples = 2\nvalue = 12.265'),
#  Text(0.007802142733560351, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 12.429'),
#  Text(0.007882811091387146, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 12.101'),
#  Text(0.007842476912473749, 0.7727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.008124816164867531, 0.7909090909090909, 'X[51] <= 0.342\nsquared_error = 0.43\nsamples = 7\nvalue = 10.643'),
#  Text(0.008044147807040736, 0.7727272727272727, 'X[56] <= 0.844\nsquared_error = 0.045\nsamples = 4\nvalue = 10.123'),
#  Text(0.008003813628127339, 0.7545454545454545, 'X[43] <= 0.274\nsquared_error = 0.008\nsamples = 3\nvalue = 10.01'),
#  Text(0.007963479449213941, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 10.127'),
#  Text(0.008044147807040736, 0.7363636363636363, 'X[62] <= 0.698\nsquared_error = 0.002\nsamples = 2\nvalue = 9.951'),
#  Text(0.008003813628127339, 0.7181818181818181, 'squared_error = 0.0\nsamples = 1\nvalue = 9.903'),
#  Text(0.008084481985954134, 0.7181818181818181, 'squared_error = 0.0\nsamples = 1\nvalue = 9.999'),
#  Text(0.008084481985954134, 0.7545454545454545, 'squared_error = 0.0\nsamples = 1\nvalue = 10.463'),
#  Text(0.008205484522694328, 0.7727272727272727, 'X[53] <= 0.617\nsquared_error = 0.103\nsamples = 3\nvalue = 11.336'),
#  Text(0.00816515034378093, 0.7545454545454545, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.008245818701607725, 0.7545454545454545, 'X[42] <= -2.0\nsquared_error = 0.022\nsamples = 2\nvalue = 11.546'),
#  Text(0.008205484522694328, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 11.396'),
#  Text(0.008286152880521123, 0.7363636363636363, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.008044147807040736, 0.8090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.008366821238347918, 0.8454545454545455, 'X[59] <= 0.915\nsquared_error = 18.318\nsamples = 6\nvalue = 9.548'),
#  Text(0.00832648705943452, 0.8272727272727273, 'X[47] <= 0.26\nsquared_error = 0.101\nsamples = 5\nvalue = 11.458'),
#  Text(0.008245818701607725, 0.8090909090909091, 'X[56] <= 0.371\nsquared_error = 0.004\nsamples = 2\nvalue = 11.096'),
#  Text(0.008205484522694328, 0.7909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.008286152880521123, 0.7909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.035'),
#  Text(0.008407155417261315, 0.8090909090909091, 'X[7] <= 1.5\nsquared_error = 0.02\nsamples = 3\nvalue = 11.699'),
#  Text(0.008366821238347918, 0.7909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.008447489596174713, 0.7909090909090909, 'X[48] <= 0.556\nsquared_error = 0.003\nsamples = 2\nvalue = 11.793'),
#  Text(0.008407155417261315, 0.7727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.00848782377508811, 0.7727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.008407155417261315, 0.8272727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.008608826311828303, 0.8636363636363636, 'X[53] <= 0.497\nsquared_error = 19.254\nsamples = 5\nvalue = 8.754'),
#  Text(0.008568492132914905, 0.8454545454545455, 'X[49] <= 0.442\nsquared_error = 0.121\nsamples = 4\nvalue = 10.942'),
#  Text(0.008528157954001508, 0.8272727272727273, 'X[60] <= 0.8\nsquared_error = 0.004\nsamples = 2\nvalue = 11.288'),
#  Text(0.00848782377508811, 0.8090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.008568492132914905, 0.8090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.008608826311828303, 0.8272727272727273, 'squared_error = 0.0\nsamples = 2\nvalue = 10.597'),
#  Text(0.0086491604907417, 0.8454545454545455, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.07504028844473373, 0.8818181818181818, 'X[29] <= 0.5\nsquared_error = 0.543\nsamples = 3506\nvalue = 11.568'),
#  Text(0.02919233433017657, 0.8636363636363636, 'X[62] <= 0.006\nsquared_error = 0.62\nsamples = 1493\nvalue = 11.455'),
#  Text(0.010004451924386412, 0.8454545454545455, 'X[62] <= 0.005\nsquared_error = 18.65\nsamples = 6\nvalue = 9.643'),
#  Text(0.009964117745473015, 0.8272727272727273, 'X[58] <= 0.453\nsquared_error = 0.062\nsamples = 5\nvalue = 11.572'),
# ...
#  Text(0.014174943001877174, 0.5363636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 12.211'),
#  Text(0.01425561135970397, 0.5363636363636364, 'X[43] <= 0.455\nsquared_error = 0.001\nsamples = 2\nvalue = 12.013'),
#  Text(0.014215277180790572, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 12.044'),
#  Text(0.014295945538617367, 0.5181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 11.983'),
#  Text(0.014497616433184354, 0.5545454545454546, 'X[47] <= 0.708\nsquared_error = 0.012\nsamples = 7\nvalue = 11.802'),
#  Text(0.01441694807535756, 0.5363636363636364, 'X[47] <= 0.54\nsquared_error = 0.003\nsamples = 5\nvalue = 11.862'),
#  Text(0.014376613896444162, 0.5181818181818182, 'X[62] <= 0.694\nsquared_error = 0.001\nsamples = 4\nvalue = 11.84'),
#  Text(0.014336279717530764, 0.5, 'X[52] <= 0.635\nsquared_error = 0.0\nsamples = 3\nvalue = 11.861'),
#  Text(0.014295945538617367, 0.4818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.014376613896444162, 0.4818181818181818, 'X[46] <= 0.562\nsquared_error = 0.0\nsamples = 2\nvalue = 11.867'),
#  Text(0.014336279717530764, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.864'),
#  Text(0.01441694807535756, 0.4636363636363636, 'squared_error = -0.0\nsamples = 1\nvalue = 11.871'),
#  Text(0.01441694807535756, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.014457282254270957, 0.5181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 11.951'),
#  Text(0.01457828479101115, 0.5363636363636364, 'X[55] <= 0.402\nsquared_error = 0.002\nsamples = 2\nvalue = 11.652'),
#  Text(0.014537950612097752, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.014618618969924549, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.014991710124873476, 0.5727272727272728, 'X[59] <= 0.423\nsquared_error = 0.033\nsamples = 12\nvalue = 11.5'),
#  Text(0.014820289864491536, 0.5545454545454546, 'X[52] <= 0.693\nsquared_error = 0.007\nsamples = 5\nvalue = 11.326'),
#  Text(0.014739621506664741, 0.5363636363636364, 'X[61] <= 0.095\nsquared_error = 0.001\nsamples = 3\nvalue = 11.388'),
#  Text(0.014699287327751344, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.44'),
#  Text(0.014779955685578139, 0.5181818181818182, 'X[55] <= 0.499\nsquared_error = 0.0\nsamples = 2\nvalue = 11.362'),
#  Text(0.014739621506664741, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.374'),
#  Text(0.014820289864491536, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.014900958222318331, 0.5363636363636364, 'X[0] <= 28284.602\nsquared_error = 0.0\nsamples = 2\nvalue = 11.232'),
#  Text(0.014860624043404934, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.238'),
#  Text(0.014941292401231729, 0.5181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.015163130385255415, 0.5545454545454546, 'X[53] <= 0.443\nsquared_error = 0.015\nsamples = 7\nvalue = 11.624'),
#  Text(0.015062294937971921, 0.5363636363636364, 'X[52] <= 0.815\nsquared_error = 0.001\nsamples = 2\nvalue = 11.798'),
#  Text(0.015021960759058524, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.82'),
#  Text(0.015102629116885318, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.775'),
#  Text(0.01526396583253891, 0.5363636363636364, 'X[59] <= 0.873\nsquared_error = 0.004\nsamples = 5\nvalue = 11.554'),
#  Text(0.015183297474712113, 0.5181818181818182, 'X[53] <= 0.896\nsquared_error = 0.001\nsamples = 3\nvalue = 11.599'),
#  Text(0.015142963295798716, 0.5, 'X[5] <= 0.5\nsquared_error = 0.0\nsamples = 2\nvalue = 11.617'),
#  Text(0.015102629116885318, 0.4818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.608'),
#  Text(0.015183297474712113, 0.4818181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 11.626'),
#  Text(0.015223631653625513, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.562'),
#  Text(0.015344634190365705, 0.5181818181818182, 'X[46] <= 0.524\nsquared_error = 0.001\nsamples = 2\nvalue = 11.487'),
#  Text(0.015304300011452308, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.015384968369279103, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.01825751817376764, 0.5909090909090909, 'X[57] <= 0.621\nsquared_error = 0.141\nsamples = 112\nvalue = 11.357'),
#  Text(0.01708782698527911, 0.5727272727272728, 'X[45] <= 0.632\nsquared_error = 0.112\nsamples = 78\nvalue = 11.428'),
#  Text(0.01617652663045453, 0.5545454545454546, 'X[47] <= 0.803\nsquared_error = 0.113\nsamples = 50\nvalue = 11.351'),
#  Text(0.01571268357295046, 0.5363636363636364, 'X[17] <= -3.5\nsquared_error = 0.09\nsamples = 35\nvalue = 11.429'),
#  Text(0.015672349394037062, 0.5181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.015753017751863857, 0.5181818181818182, 'X[53] <= 0.58\nsquared_error = 0.072\nsamples = 34\nvalue = 11.454'),
#  Text(0.015465636727105898, 0.5, 'X[48] <= 0.733\nsquared_error = 0.05\nsamples = 15\nvalue = 11.311'),
#  Text(0.015354717735094054, 0.4818181818181818, 'X[51] <= 0.361\nsquared_error = 0.022\nsamples = 13\nvalue = 11.379'),
#  Text(0.01525388228781056, 0.4636363636363636, 'X[48] <= 0.372\nsquared_error = 0.004\nsamples = 4\nvalue = 11.223'),
#  Text(0.015213548108897162, 0.44545454545454544, 'squared_error = 0.0\nsamples = 2\nvalue = 11.29'),
#  Text(0.015294216466723957, 0.44545454545454544, 'squared_error = -0.0\nsamples = 2\nvalue = 11.156'),
#  Text(0.015455553182377547, 0.4636363636363636, 'X[58] <= 0.469\nsquared_error = 0.014\nsamples = 9\nvalue = 11.449'),
#  Text(0.015374884824550752, 0.44545454545454544, 'X[52] <= 0.698\nsquared_error = 0.002\nsamples = 4\nvalue = 11.35'),
#  Text(0.015334550645637355, 0.42727272727272725, 'X[45] <= 0.294\nsquared_error = 0.001\nsamples = 3\nvalue = 11.369'),
#  Text(0.015294216466723957, 0.4090909090909091, 'X[52] <= 0.447\nsquared_error = 0.0\nsamples = 2\nvalue = 11.35'),
#  Text(0.01525388228781056, 0.39090909090909093, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.015334550645637355, 0.39090909090909093, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.015374884824550752, 0.4090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.01541521900346415, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.015536221540204344, 0.44545454545454544, 'X[58] <= 0.591\nsquared_error = 0.01\nsamples = 5\nvalue = 11.528'),
#  Text(0.015495887361290947, 0.42727272727272725, 'squared_error = 0.0\nsamples = 3\nvalue = 11.608'),
#  Text(0.015576555719117742, 0.42727272727272725, 'squared_error = -0.0\nsamples = 2\nvalue = 11.408'),
#  Text(0.015576555719117742, 0.4818181818181818, 'X[43] <= 0.232\nsquared_error = 0.002\nsamples = 2\nvalue = 10.867'),
#  Text(0.015536221540204344, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.01561688989803114, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 10.82'),
#  Text(0.016040398776621813, 0.5, 'X[54] <= 0.675\nsquared_error = 0.06\nsamples = 19\nvalue = 11.566'),
#  Text(0.015778226613684727, 0.4818181818181818, 'X[54] <= 0.135\nsquared_error = 0.033\nsamples = 13\nvalue = 11.455'),
#  Text(0.01573789243477133, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.918'),
#  Text(0.01581856079259813, 0.4636363636363636, 'X[44] <= 0.326\nsquared_error = 0.016\nsamples = 12\nvalue = 11.416'),
#  Text(0.015697558255857932, 0.44545454545454544, 'X[15] <= 1.5\nsquared_error = 0.001\nsamples = 2\nvalue = 11.191'),
#  Text(0.015657224076944535, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.01573789243477133, 0.42727272727272725, 'squared_error = -0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.01593956332933832, 0.44545454545454544, 'X[1] <= 1025.0\nsquared_error = 0.007\nsamples = 10\nvalue = 11.461'),
#  Text(0.01581856079259813, 0.42727272727272725, 'X[62] <= 0.512\nsquared_error = 0.002\nsamples = 3\nvalue = 11.349'),
#  Text(0.015778226613684727, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.015858894971511526, 0.4090909090909091, 'X[62] <= 0.861\nsquared_error = 0.001\nsamples = 2\nvalue = 11.379'),
#  Text(0.01581856079259813, 0.39090909090909093, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.015899229150424923, 0.39090909090909093, 'squared_error = 0.0\nsamples = 1\nvalue = 11.408'),
#  Text(0.016060565866078513, 0.42727272727272725, 'X[59] <= 0.683\nsquared_error = 0.001\nsamples = 7\nvalue = 11.51'),
#  Text(0.016020231687165116, 0.4090909090909091, 'X[58] <= 0.233\nsquared_error = 0.0\nsamples = 6\nvalue = 11.521'),
#  Text(0.01597989750825172, 0.39090909090909093, 'squared_error = 0.0\nsamples = 1\nvalue = 11.562'),
#  Text(0.016060565866078513, 0.39090909090909093, 'squared_error = 0.0\nsamples = 5\nvalue = 11.513'),
#  Text(0.01610090004499191, 0.4090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 11.44'),
#  Text(0.0163025709395589, 0.4818181818181818, 'X[45] <= 0.217\nsquared_error = 0.035\nsamples = 6\nvalue = 11.808'),
#  Text(0.016221902581732103, 0.4636363636363636, 'X[53] <= 0.823\nsquared_error = 0.008\nsamples = 3\nvalue = 11.968'),
#  Text(0.016181568402818706, 0.44545454545454544, 'X[49] <= 0.089\nsquared_error = 0.002\nsamples = 2\nvalue = 12.028'),
#  Text(0.01614123422390531, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 11.983'),
#  Text(0.016221902581732103, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 12.073'),
#  Text(0.0162622367606455, 0.44545454545454544, 'squared_error = -0.0\nsamples = 1\nvalue = 11.849'),
#  Text(0.016383239297385693, 0.4636363636363636, 'X[32] <= 0.5\nsquared_error = 0.009\nsamples = 3\nvalue = 11.648'),
#  Text(0.016342905118472296, 0.44545454545454544, 'X[0] <= 4075.0\nsquared_error = 0.0\nsamples = 2\nvalue = 11.716'),
#  Text(0.0163025709395589, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.016383239297385693, 0.42727272727272725, 'squared_error = -0.0\nsamples = 1\nvalue = 11.736'),
#  Text(0.01642357347629909, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.016640369687958602, 0.5363636363636364, 'X[2] <= 1924.5\nsquared_error = 0.121\nsamples = 15\nvalue = 11.168'),
#  Text(0.01648407474466919, 0.5181818181818182, 'X[43] <= 0.692\nsquared_error = 0.0\nsamples = 2\nvalue = 10.584'),
#  Text(0.01644374056575579, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 10.597'),
#  Text(0.016524408923582586, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 10.571'),
#  Text(0.01679666463124802, 0.5181818181818182, 'X[59] <= 0.381\nsquared_error = 0.078\nsamples = 13\nvalue = 11.258'),
#  Text(0.01660507728140938, 0.5, 'X[58] <= 0.422\nsquared_error = 0.063\nsamples = 6\nvalue = 11.465'),
#  Text(0.016504241834125886, 0.4818181818181818, 'X[58] <= 0.205\nsquared_error = 0.005\nsamples = 2\nvalue = 11.154'),
#  Text(0.01646390765521249, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.016544576013039283, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.225'),
#  Text(0.016705912728692873, 0.4818181818181818, 'X[9] <= 1.5\nsquared_error = 0.02\nsamples = 4\nvalue = 11.621'),
#  Text(0.016625244370866078, 0.4636363636363636, 'X[53] <= 0.895\nsquared_error = 0.003\nsamples = 2\nvalue = 11.754'),
#  Text(0.01658491019195268, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.695'),
#  Text(0.016665578549779476, 0.44545454545454544, 'squared_error = -0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.016786581086519668, 0.4636363636363636, 'X[47] <= 0.939\nsquared_error = 0.001\nsamples = 2\nvalue = 11.487'),
#  Text(0.01674624690760627, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.513'),
#  Text(0.016826915265433066, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.01698825198108666, 0.5, 'X[50] <= 0.196\nsquared_error = 0.023\nsamples = 7\nvalue = 11.081'),
#  Text(0.016947917802173258, 0.4818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 11.29'),
#  Text(0.017028586160000057, 0.4818181818181818, 'X[58] <= 0.515\nsquared_error = 0.008\nsamples = 5\nvalue = 10.998'),
#  Text(0.016947917802173258, 0.4636363636363636, 'X[17] <= 1.5\nsquared_error = 0.001\nsamples = 3\nvalue = 10.933'),
#  Text(0.01690758362325986, 0.44545454545454544, 'X[0] <= 9750.0\nsquared_error = 0.0\nsamples = 2\nvalue = 10.915'),
#  Text(0.016867249444346463, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.016947917802173258, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 10.915'),
#  Text(0.01698825198108666, 0.44545454545454544, 'squared_error = -0.0\nsamples = 1\nvalue = 10.968'),
#  Text(0.01710925451782685, 0.4636363636363636, 'X[61] <= 0.86\nsquared_error = 0.004\nsamples = 2\nvalue = 11.096'),
#  Text(0.017068920338913454, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.01714958869674025, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.035'),
#  Text(0.017999127340103685, 0.5545454545454546, 'X[46] <= 0.753\nsquared_error = 0.081\nsamples = 28\nvalue = 11.565'),
#  Text(0.01769914188443529, 0.5363636363636364, 'X[37] <= 1.5\nsquared_error = 0.031\nsamples = 19\nvalue = 11.438'),
#  Text(0.017522679851689177, 0.5181818181818182, 'X[44] <= 0.802\nsquared_error = 0.014\nsamples = 15\nvalue = 11.367'),
#  Text(0.017331092501850536, 0.5, 'X[44] <= 0.057\nsquared_error = 0.004\nsamples = 11\nvalue = 11.42'),
#  Text(0.017230257054567044, 0.4818181818181818, 'X[62] <= 0.479\nsquared_error = 0.001\nsamples = 2\nvalue = 11.314'),
#  Text(0.017189922875653647, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.01727059123348044, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.277'),
#  Text(0.01743192794913403, 0.4818181818181818, 'X[54] <= 0.405\nsquared_error = 0.002\nsamples = 9\nvalue = 11.444'),
#  Text(0.017351259591307237, 0.4636363636363636, 'X[59] <= 0.117\nsquared_error = 0.0\nsamples = 6\nvalue = 11.415'),
#  Text(0.01731092541239384, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.462'),
#  Text(0.017391593770220634, 0.44545454545454544, 'X[58] <= 0.126\nsquared_error = 0.0\nsamples = 5\nvalue = 11.405'),
#  Text(0.017351259591307237, 0.42727272727272725, 'squared_error = 0.0\nsamples = 1\nvalue = 11.396'),
#  Text(0.01743192794913403, 0.42727272727272725, 'squared_error = -0.0\nsamples = 4\nvalue = 11.408'),
#  Text(0.017512596306960827, 0.4636363636363636, 'X[61] <= 0.41\nsquared_error = 0.0\nsamples = 3\nvalue = 11.503'),
#  Text(0.01747226212804743, 0.44545454545454544, 'squared_error = 0.0\nsamples = 1\nvalue = 11.482'),
#  Text(0.017552930485874224, 0.44545454545454544, 'squared_error = -0.0\nsamples = 2\nvalue = 11.513'),
#  Text(0.017714267201527814, 0.5, 'X[62] <= 0.743\nsquared_error = 0.011\nsamples = 4\nvalue = 11.22'),
#  Text(0.01763359884370102, 0.4818181818181818, 'X[41] <= 0.5\nsquared_error = 0.001\nsamples = 2\nvalue = 11.119'),
#  Text(0.01759326466478762, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.082'),
#  Text(0.017673933022614417, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.156'),
#  Text(0.01779493555935461, 0.4818181818181818, 'X[62] <= 0.981\nsquared_error = 0.001\nsamples = 2\nvalue = 11.32'),
#  Text(0.01775460138044121, 0.4636363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 11.29'),
#  Text(0.017835269738268007, 0.4636363636363636, 'squared_error = -0.0\nsamples = 1\nvalue = 11.35'),
#  Text(0.017875603917181404, 0.5181818181818182, 'X[46] <= 0.13\nsquared_error = 0.005\nsamples = 4\nvalue = 11.703'),
#  Text(0.017835269738268007, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 11.813'),
#  Text(0.0179159380960948, 0.5, 'X[56] <= 0.462\nsquared_error = 0.002\nsamples = 3\nvalue = 11.666'),
#  Text(0.017875603917181404, 0.4818181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 11.695'),
#  ...]

# %% [markdown]
# To reduce the complexity of the tree, we **prune** the tree: we collapse its leaves, permitting bias to increase but forcing variance to decrease until the desired trade-off is achieved. In `rpart`, this is done by considering a modified loss function that takes into account the number of terminal nodes (i.e., the number of regions in which the original data was partitioned). Somewhat heuristically, if we denote tree predictions by $T(x)$ and its number of terminal nodes by  $|T|$, the modified regression problem can be written as:
#
#
#
#   $
#   \widehat{T} = \arg\min_{T} \sum_{i=1}^m \left( T(X_i) - Y_i \right)^2 + c_p |T|
#  $
#
#
# The complexity of the tree is controlled by the scalar parameter $c_p$, denoted as `cp` in `rpart`. For each value of $c_p$, we find the subtree that solves \@ref(eq:tree-cp). Large values of $c_p$ lead to aggressively pruned trees, which have more bias and less variance. Small values of $c_p$ allow for deeper trees whose predictions can vary more wildly. The plot below shows the cross-validated error (relative to a tree with only one node, which corresponds to predicting the sample mean everywhere) for trees obtained at different levels of  $c_p$. The bias-variance trade-off is optimized at the point at which the cross-validated error is minimized.

# %%
tree     = DecisionTreeRegressor(random_state=0)
path = tree.cost_complexity_pruning_path(X,Y)
ccp_alphas, impurities = path.ccp_alphas, path.impurities
fig, ax = plt.subplots() 
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("effective alpha")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective alpha for training set")
# Out:
# Text(0.5, 1.0, 'Total Impurity vs effective alpha for training set')

# %%
mean_error = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeRegressor(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(X,Y)
    yhat = clf.predict(X)
    mean_error.append(mean_squared_error(Y,yhat))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20276/346980654.py in <module>
#       2 for ccp_alpha in ccp_alphas:
#       3     clf = DecisionTreeRegressor(random_state=0, ccp_alpha=ccp_alpha)
# ----> 4     clf.fit(X,Y)
#       5     yhat = clf.predict(X)
#       6     mean_error.append(mean_squared_error(Y,yhat))
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
ccp_alphas

# %%
plt.plot(ccp_alphas, mean_error)

# %% [markdown]
# The following code retrieves the optimal parameter and prunes the tree. Here, instead of choosing the parameter that minimizes the mean-squared-error, we're following another common heuristic: we will choose the most regularized model whose error is within one standard error of the minimum error.

# %% [markdown]
# Plotting the pruned tree. See also the package [rpart.plot](http://www.milbo.org/rpart-plot/prp.pdf) for more advanced plotting capabilities.
# ```{r}

# %% [markdown]
# Finally, here’s how to extract predictions and mse estimates from the pruned tree.

# %% [markdown]
# It’s often said that trees are "interpretable." To some extent, that’s true – we can look at the tree and clearly visualize the mapping from inputs to prediction. This can be important in settings in which conveying how one got to a prediction is important. For example, if a decision tree were to be used for credit scoring, it would be easy to explain to a client how their credit was scored.
#
# Beyond that, however, there are several reasons for not interpreting the obtained decision tree further. First, even though a tree may have used a particular variable for a split, that does not mean that it’s indeed an important variable: if two covariates are highly correlated, the tree may split on one variable but not the other, and there’s no guarantee which variables are relevant in the underlying data-generating process.
#
# Similar to what we did for Lasso above, we can estimate the average value of each covariate per leaf. Although results are noisier here because there are many leaves, we see somewhat similar trends in that houses with higher predictions are also correlated with more bedrooms, bathrooms and room sizes.

# %% [markdown]
# Finally, as we did in the linear model case, we can use the same code for an annotated version of the same information. Again, we ordered the rows in decreasing order based on an estimate of the relative variance "explained" by leaf membership: $Var(E[X_i|L_i]) / Var(X_i)$, where $L_i$ represents the leaf.

# %% [markdown]
# ### Forest

# %% [markdown]
# Forests are a type of **ensemble** estimators: they aggregate information about many decision trees to compute a new estimate that typically has much smaller variance.
#
# At a high level, the process of fitting a (regression) forest consists of fitting many decision trees, each on a different subsample of the data. The forest prediction for a particular point $x$ is the average of all tree predictions for that point.
#
# One interesting aspect of forests and many other ensemble methods is that cross-validation can be built into the algorithm itself. Since each tree only uses a subset of the data, the remaining subset is effectively a test set for that tree. We call these observations **out-of-bag** (there were not in the “bag” of training observations). They can be used to evaluate the performance of that tree, and the average of out-of-bag evaluations is evidence of the performance of the forest itself.
#
# For the example below, we’ll use the regression_forest function of the `R` package `grf`. The particular forest implementation in `grf` has interesting properties that are absent from most other packages. For example, trees are build using a certain sample-splitting scheme that ensures that predictions are approximately unbiased and normally distributed for large samples, which in turn allows us to compute valid confidence intervals around those predictions. We’ll have more to say about the importance of these features when we talk about causal estimates in future chapters. See also the grf website for more information.

# %% [markdown]
# The function `variable_importance` computes a simple weighted sum of how many times each feature was split on at each depth across the trees.

# %% [markdown]
# All the caveats about interpretation that we mentioned above apply in a similar to forest output.

# %% [markdown]
# ## Further reading

# %% [markdown]
# In this tutorial we briefly reviewed some key concepts that we recur later in this tutorial. For readers who are entirely new to this field or interested in learning about it more depth, the first few chapters of the following textbook are an acccessible introduction:
#
# James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An introduction to statistical learning (Vol. 112, p. 18). New York: springer. Available for free at [the authors’ website](https://www.statlearning.com/).
#
# Some of the discussion in the Lasso section in particular was drawn from [Mullainathan and Spiess (JEP, 2017)](https://www.aeaweb.org/articles?id=10.1257/jep.31.2.87), which contains a good discussion of the interpretability issues discussed here.
#
# There has been a good deal of research on inference in high-dimensional models, Although we won’t be covering in depth it in this tutorial, we refer readers to [Belloni, Chernozhukov and Hansen (JEP, 2014)](http://www.mit.edu/~vchern/papers/JEP.pdf). Also check out the related `R` package [`hdm`](https://cran.r-project.org/web/packages/hdm/hdm.pdf), developed by the same authors, along with Philipp Bach and Martin Spindler.
